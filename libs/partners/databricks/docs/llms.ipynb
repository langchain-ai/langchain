# %% [raw]
# ---
# sidebar_label: Databricks
# ---

# %% [markdown]
# # DatabricksLLM
#
# - [ ] TODO: Make sure API reference link is correct
#
# This will help you get started with Databricks completion models (LLMs) using LangChain. For detailed documentation on `DatabricksLLM` features and configuration options, please refer to the [API reference](https://api.python.langchain.com/en/latest/llms/langchain_databricks.llms.DatabricksLLM.html).
#
# ## Overview
# ### Integration details
#
# - TODO: Fill in table features.
# - TODO: Remove JS support link if not relevant, otherwise ensure link is correct.
# - TODO: Make sure API reference links are correct.
#
# | Class | Package | Local | Serializable | [JS support](https://js.langchain.com/v0.2/docs/integrations/llms/databricks) | Package downloads | Package latest |
# | :--- | :--- | :---: | :---: |  :---: | :---: | :---: |
# | [DatabricksLLM](https://api.python.langchain.com/en/latest/llms/langchain_databricks.llms.DatabricksLLM.html) | [langchain-databricks](https://api.python.langchain.com/en/latest/databricks_api_reference.html) | ✅/❌ | beta/❌ | ✅/❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/langchain-databricks?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/langchain-databricks?style=flat-square&label=%20) |
#
# ## Setup
#
# - [ ] TODO: Update with relevant info.
#
# To access Databricks models you'll need to create a/an Databricks account, get an API key, and install the `langchain-databricks` integration package.
#
# ### Credentials
#
# - TODO: Update with relevant info.
#
# Head to (TODO: link) to sign up to Databricks and generate an API key. Once you've done this set the DATABRICKS_API_KEY environment variable:

# %%
import getpass
import os

if not os.getenv("DATABRICKS_API_KEY"):
    os.environ["DATABRICKS_API_KEY"] = getpass.getpass("Enter your Databricks API key: ")

# %% [markdown]
# If you want to get automated tracing of your model calls you can also set your [LangSmith](https://docs.smith.langchain.com/) API key by uncommenting below:

# %%
# os.environ["LANGCHAIN_TRACING_V2"] = "true"
# os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")

# %% [markdown]
# ### Installation
#
# The LangChain Databricks integration lives in the `langchain-databricks` package:

# %%
# %pip install -qU langchain-databricks

# %% [markdown]
# ## Instantiation
#
# Now we can instantiate our model object and generate chat completions:
#
# - TODO: Update model instantiation with relevant params.

# %%
from langchain_databricks import DatabricksLLM

llm = DatabricksLLM(
    model="model-name",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %% [markdown]
# ## Invocation
#
# - [ ] TODO: Run cells so output can be seen.

# %%
input_text = "Databricks is an AI company that "

completion = llm.invoke(input_text)
completion

# %% [markdown]
# ## Chaining
#
# We can [chain](/docs/how_to/sequence/) our completion model with a prompt template like so:
#
# - TODO: Run cells so output can be seen.

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    "How to say {input} in {output_language}:\n"
)

chain = prompt | llm
chain.invoke(
    {
        "output_language": "German",
        "input": "I love programming.",
    }
)

# %% [markdown]
# ## TODO: Any functionality specific to this model provider
#
# E.g. creating/using finetuned models via this provider. Delete if not relevant

# %% [markdown]
# ## API reference
#
# For detailed documentation of all `DatabricksLLM` features and configurations head to the API reference: https://api.python.langchain.com/en/latest/llms/langchain_databricks.llms.DatabricksLLM.html
