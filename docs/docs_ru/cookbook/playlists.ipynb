# %% [markdown]
# # Получение рекомендаций в Spotify с помощью GigaChat
#
# Блокнот перенесен в [основной раздел с примерами](https://github.com/ai-forever/gigachain/blob/master/cookbook/playlists.ipynb).
