# %% [markdown]
# # Создание агента для работы с функциями GigaChat
#
# Блокнот перенесен в [основной раздел с примерами](https://github.com/ai-forever/gigachain/blob/master/cookbook/gigachat_functions_agent.ipynb).
