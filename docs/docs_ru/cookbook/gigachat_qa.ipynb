# %% [markdown]
# # Retrieval Augmented Generation(RAG) с использованием GigaChat на примере задачи "разговор с книгой"
#
# Блокнот перенесен в [основной раздел с примерами](https://github.com/ai-forever/gigachain/blob/master/cookbook/gigachat_qa.ipynb).
