# %%
# !pip install slack_bolt

# %%
# !pip install slack_sdk
! export SLACK_BOT_TOKEN=xoxb-6040211441731-6065315841232-fB1RkCDxWRsTy8fKOMvD9Opc

# %%
from langchain.agents.agent_toolkits import SlackToolkit

toolkit = SlackToolkit()
tools = toolkit.get_tools()
tools
# Out:
# slack auth start
# get client
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain.agents.agent_toolkits import SlackToolkit
#       3 toolkit = SlackToolkit()
# ----> 4 tools = toolkit.get_tools()
#       5 tools
#
# File /workspaces/langchain/libs/langchain/langchain/agents/agent_toolkits/slack/toolkit.py:34, in SlackToolkit.get_tools(self)
#      30 def get_tools(self) -> List[SlackBaseTool]:
#      31     """Get the tools in the toolkit."""
#      32     return [
#      33         # SlackSendMessage(client=self.client),
# ---> 34         SlackSendMessage(),
#      35     ]
#
# File ~/langchain-py-env/lib/python3.11/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for SlackSendMessage
# client
#   field required (type=value_error.missing)

# %%
# set env var: SLACK_BOT_TOKEN, SLACK_USR_TOKEN, SLACK_APP_TOKEN
# e.g. export SLACK_BOT_TOKEN=xoxb-<your-bot-token>
