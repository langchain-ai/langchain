# %% [markdown]
# # Рекомендации
#
# Качество извлечения информации зависит от множества факторов.
#
# Для получения наилучших результатов при работе с моделями, следуйте следующим рекомендациям:
#
# * установите значение температуры — 0;
# * доработайте промпт. Он должен быть как можно более точным и конкретным;
# * подробно опишите схему;
# * предоставьте модели по возможности больше различных примеров, в том числе тех случаев, когда извлекать ничего не нужно;
# * при работе с множеством примеров используйте ретривер, чтобы работать с наиболее подходящими;
# * при работе с большой схемой попробуйте разделисть ее на несколько схем поменьше, извлечь информацию на их основе и объединить итоговые результаты;
# * убедить, что схема позволяет модели не извлекать информацию. В противном случае модель будет вынуждена придумывать несуществующие данные.
# * добавьте этапы проверки/исправления: попросите модель проверить или исправить данные после их извлечения.
#
# <!--
# ## Benchmark
#
# * Create and benchmark data for your use case using [LangSmith 🦜️🛠️](https://docs.smith.langchain.com/).
# * Is your LLM good enough? Use [langchain-benchmarks 🦜💯 ](https://github.com/langchain-ai/langchain-benchmarks) to test out your LLM using existing datasets.
# -->
#
# :::note
#
# * LLM могут быть очень полезны для решения определенных задач и, в то же время, избыточны в других. Например, если вам нужно извлечь данные из одного источника, в котором уже хранятся структурированные данные, традиционные подходы будут дешевле и надежнее, чем LLM.
# * Использование подхода человек-в-цикле. Если вам нужно идеальное качество, в радеботе LLM следует предусмотреть этап, на котором полученные данные сможет проверить человек. Это особенно актуально в сложных задачах по извлечению.
#
# :::
