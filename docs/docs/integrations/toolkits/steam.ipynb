# %%
import os
import sys
print(sys.path)
from langchain.agents import AgentType, initialize_agent
from langchain.agents.agent_toolkits.steam.toolkit import SteamToolkit
from langchain.utilities.steam import SteamWebAPIWrapper
from langchain.llms import OpenAI
# Out:
# ['/Users/johnyuan/Documents/GitHub/langchain/docs/docs/integrations/toolkits', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload', '', '/Users/johnyuan/Library/Python/3.12/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages']

# %%
os.environ["STEAM_KEY"] = "steam_key"
os.environ["STEAM_ID"] = "123"
os.environ["OPENAI_API_KEY"] = "xyz"
os.environ["steam_key"] = "cdf"

# %%
llm = OpenAI(temperature=0)
Steam = SteamWebAPIWrapper()
toolkit = SteamToolkit.from_steam_api_wrapper(Steam)
agent = initialize_agent(
    toolkit.get_tools(), llm, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True
)

# %%
out = agent({"input": "can you give the information about the game whose appid is 730", "'request'": "appdetail"})
print(out)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /Users/johnyuan/Documents/GitHub/langchain/docs/docs/integrations/toolkits/steam.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/johnyuan/Documents/GitHub/langchain/docs/docs/integrations/toolkits/steam.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> out = agent({"input": "can you give the information about the game whose appid is 730", "'request'": "appdetail"})
#       <a href='vscode-notebook-cell:/Users/johnyuan/Documents/GitHub/langchain/docs/docs/integrations/toolkits/steam.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> print(out)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langchain/chains/base.py:310, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     308 except BaseException as e:
# ...
