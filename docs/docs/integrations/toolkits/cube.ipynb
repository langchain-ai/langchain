# %% [markdown]
# # Cube Semantic Layer
#
# This notebook showcases an agent interacting with a Cube Semantic Layer. The agent is answering more general questions about a Cube Semantic Layer, as well as recover from errors.
#
# Note that, as this agent is in active development, all answers might not be correct.
#
# Sample data for this notebook is sourced from the Cube examples, available at [active-users-example](https://github.com/cube-js/cube/tree/master/examples/recipes/active-users).
#
# ![cube_semantic_layer_agent.png](/img/cube_semantic_layer_agent.png)

# %% [markdown]
# ## Note
# - Uses rest API to interact with the data [https://cube.dev/docs/reference/rest-api](https://cube.dev/docs/reference/rest-api)
# - Cube FAQs, Tips and Tricks [https://cube.dev/docs/product/faqs/tips-and-tricks](https://cube.dev/docs/product/faqs/tips-and-tricks)

# %% [markdown]
# ## Initialization

# %%
from langchain.agents.agent_toolkits import CubeToolkit, create_cube_agent
from langchain.chat_models import ErnieBotChat
from langchain.llms.openai import OpenAI
from langchain.pydantic_v1 import SecretStr
from langchain.utilities.cube import Cube

# %%
openai = OpenAI(
    temperature=0,
    verbose=True,
)

ernie = ErnieBotChat(
    temperature=0.5,
    model_name="ERNIE-Bot-4",
    verbose=True,
)

# %% [markdown]
# ## Create the Cube Toolkit

# %%
cube = Cube(
    cube_api_url="http://localhost:4000/cubejs-api/v1",
    cube_api_token=SecretStr("CUBE_API_TOKEN"),
)

toolkit = CubeToolkit(
    cube=cube,
    llm=ernie,
)

# %% [markdown]
# ## Use within a Cube Agent

# %%
agent_executor = create_cube_agent(
    llm=openai,
    toolkit=toolkit,
    verbose=True,
)

# %% [markdown]
# ## Example: Daily, Weekly, Monthly Active Users (DAU, WAU, MAU)

# %%
result = agent_executor.run(
    "Obtain this 2020 year's data for daily, weekly, monthly, and WAU to MAU active users. Use a Markdown table to present this data."
)
# Out:
# > Entering new AgentExecutor chain...
# Action: list_models_cube
# Action Input: ""
# Observation: | Model | Description |
# | --- | --- |
# | ActiveUsers | None |
#
# Thought: I should query the meta-information of the ActiveUsers model.
# Action: meta_information_cube
# Action Input: "ActiveUsers"
# Observation: ## Model: ActiveUsers
#
# ### Measures:
# | Title | Description | Column | Type |
# | --- | --- | --- | --- |
# | Active Users Monthly Active Users | None | ActiveUsers.monthlyActiveUsers | number |
# | Active Users Weekly Active Users | None | ActiveUsers.weeklyActiveUsers | number |
# | Active Users Daily Active Users | None | ActiveUsers.dailyActiveUsers | number |
# | Active Users WAU to MAU | None | ActiveUsers.wauToMau | number |
#
# ### Dimensions:
# | Title | Description | Column | Type |
# | --- | --- | --- | --- |
# | Active Users Created at | None | ActiveUsers.createdAt | time |
#
# Thought: I should query the Cube for the relevant columns of the ActiveUsers model.
# Action: load_cube
# Action Input: {
#     "measures": ["ActiveUsers.monthlyActiveUsers", "ActiveUsers.weeklyActiveUsers", "ActiveUsers.dailyActiveUsers", "ActiveUsers.wauToMau"],
#     "dimensions": ["ActiveUsers.createdAt"],
#     "timeDimensions": [{
#         "dimension": "ActiveUsers.createdAt",
#         "dateRange": ["2020-01-01", "2020-12-31"],
#         "granularity": "month"
#     }],
#     "limit": 10,
#     "order": {
#         "ActiveUsers.createdAt": "asc"
#     }
# }
# Observation: [{"ActiveUsers.createdAt": "2019-12-31T00:00:00.000", "ActiveUsers.createdAt.month": "2020-01-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "4", "ActiveUsers.weeklyActiveUsers": "4", "ActiveUsers.dailyActiveUsers": "4", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-01-31T00:00:00.000", "ActiveUsers.createdAt.month": "2020-02-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "1", "ActiveUsers.weeklyActiveUsers": "1", "ActiveUsers.dailyActiveUsers": "1", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-02-29T00:00:00.000", "ActiveUsers.createdAt.month": "2020-03-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "6", "ActiveUsers.weeklyActiveUsers": "6", "ActiveUsers.dailyActiveUsers": "6", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-03-31T00:00:00.000", "ActiveUsers.createdAt.month": "2020-04-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "14", "ActiveUsers.weeklyActiveUsers": "14", "ActiveUsers.dailyActiveUsers": "14", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-04-30T00:00:00.000", "ActiveUsers.createdAt.month": "2020-05-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "1", "ActiveUsers.weeklyActiveUsers": "1", "ActiveUsers.dailyActiveUsers": "1", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-05-31T00:00:00.000", "ActiveUsers.createdAt.month": "2020-06-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "4", "ActiveUsers.weeklyActiveUsers": "4", "ActiveUsers.dailyActiveUsers": "4", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-06-30T00:00:00.000", "ActiveUsers.createdAt.month": "2020-07-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "2", "ActiveUsers.weeklyActiveUsers": "2", "ActiveUsers.dailyActiveUsers": "2", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-07-31T00:00:00.000", "ActiveUsers.createdAt.month": "2020-08-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "5", "ActiveUsers.weeklyActiveUsers": "5", "ActiveUsers.dailyActiveUsers": "5", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-08-31T00:00:00.000", "ActiveUsers.createdAt.month": "2020-09-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "8", "ActiveUsers.weeklyActiveUsers": "8", "ActiveUsers.dailyActiveUsers": "8", "ActiveUsers.wauToMau": "100.0000000000000000"}, {"ActiveUsers.createdAt": "2020-09-30T00:00:00.000", "ActiveUsers.createdAt.month": "2020-10-01T00:00:00.000", "ActiveUsers.monthlyActiveUsers": "2", "ActiveUsers.weeklyActiveUsers": "2", "ActiveUsers.dailyActiveUsers": "2", "ActiveUsers.wauToMau": "100.0000000000000000"}]
# Thought: I now know the final answer.
# Final Answer:
#
# | Date | Monthly Active Users | Weekly Active Users | Daily Active Users | WAU to MAU |
# | --- | --- | --- | --- | --- |
# | 2020-01-01 | 4 | 4 | 4 | 100.00 |
# | 2020-02-01 | 1 | 1 | 1 | 100.00 |
# | 2020-03-01 | 6 | 6 | 6 | 100.00 |
# | 2020-04-01 | 14 | 14 | 14 | 100.00 |
# | 2020-05-01 | 1 | 1 | 1 | 100.00 |
# | 2020-06-01 | 4 | 4 | 4 | 100.00 |
# | 2020-07-01 | 2 | 2 | 2 | 100.00 |
# | 2020-08-01 | 5 | 5 | 5 | 100.00 |
# | 2020-09-01 | 8 | 8 | 8 | 100.00 |
# | 2020-10-01 | 2 | 2 | 2 | 100.00 |
#
# > Finished chain.
