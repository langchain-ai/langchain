# %% [markdown]
# # Cohere RAG retriever
#
# This notebook covers how to get started with Cohere RAG retriever. This allows you to leverage the ability to search documents over various connectors or by supplying your own.

# %%
from langchain_community.chat_models import ChatCohere
from langchain_community.retrievers import CohereRagRetriever
from langchain_core.documents import Document

# %%
rag = CohereRagRetriever(llm=ChatCohere(cohere_api_key="API_KEY"))

# %%
def _pretty_print(docs):
    for doc in docs:
        print(doc.metadata)
        print("\n\n" + doc.page_content)
        print("\n\n" + "-" * 30 + "\n\n")

# %%
_pretty_print(rag.get_relevant_documents("What is cohere ai?"))
# Out:
# {'id': 'web-search_4:0', 'snippet': 'Cohere is a Canadian multinational technology company focused on artificial intelligence for the enterprise, specializing in large language models. Cohere was founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst, and is headquartered in Toronto and San Francisco, with offices in Palo Alto and London.\n\nIn 2017, a team of researchers at Google Brain, which included Aidan Gomez, published a paper called "Attention is All You Need," which introduced the transformer machine learning architecture, setting state-of-the-art performance on a variety of natural language processing tasks. In 2019, Gomez and Nick Frosst, another researcher at Google Brain, founded Cohere along with Ivan Zhang, with whom Gomez had done research at FOR.ai. All of the co-founders attended University of Toronto.', 'timestamp': '2024-03-11T12:19:29', 'title': 'Cohere - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/Cohere'}
#
#
# Cohere is a Canadian multinational technology company focused on artificial intelligence for the enterprise, specializing in large language models. Cohere was founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst, and is headquartered in Toronto and San Francisco, with offices in Palo Alto and London.
#
# In 2017, a team of researchers at Google Brain, which included Aidan Gomez, published a paper called "Attention is All You Need," which introduced the transformer machine learning architecture, setting state-of-the-art performance on a variety of natural language processing tasks. In 2019, Gomez and Nick Frosst, another researcher at Google Brain, founded Cohere along with Ivan Zhang, with whom Gomez had done research at FOR.ai. All of the co-founders attended University of Toronto.
#
#
# ------------------------------
#
#
# {'id': 'web-search_9:0', 'snippet': 'What does Cohere do?\n\nQuickly create and integrate AI large language models with your apps\n\nPhoto by Joshua J. Cotten on Unsplash\n\nCohere is an AI company specialising in large language models (LLMs), that offers a platform made available via an API enabling developers to:\n\nLeverage Cohere’s pre-built LLMs to perform common tasks on text input, such as: summarising, classification, and finding the similarities in content aka. natural language processing (NLP).\n\nCreate their own language models, based on the legwork Cohere has already done, that can be customised based on their own training data.\n\n🗝️ Key Concepts — Text Output vs. Embedding\n\nCohere provides access to two types of language model:\n\n📖 ➔ 💬 Generation Language Models: This takes text as an input and then spits out some different text, depending on the task the model is designed to achieve.', 'timestamp': '2024-03-07T21:43:27', 'title': 'What does Cohere do?. Quickly create and integrate AI large… | by Omer Mahmood | Geek Culture | Medium', 'url': 'https://medium.com/geekculture/what-does-cohere-do-cdadf6d70435'}
#
#
# What does Cohere do?
#
# Quickly create and integrate AI large language models with your apps
#
# Photo by Joshua J. Cotten on Unsplash
#
# Cohere is an AI company specialising in large language models (LLMs), that offers a platform made available via an API enabling developers to:
#
# Leverage Cohere’s pre-built LLMs to perform common tasks on text input, such as: summarising, classification, and finding the similarities in content aka. natural language processing (NLP).
#
# Create their own language models, based on the legwork Cohere has already done, that can be customised based on their own training data.
#
# 🗝️ Key Concepts — Text Output vs. Embedding
#
# Cohere provides access to two types of language model:
#
# 📖 ➔ 💬 Generation Language Models: This takes text as an input and then spits out some different text, depending on the task the model is designed to achieve.
#
#
# ------------------------------
#
#
# {'id': 'web-search_4:4', 'snippet': " Cohere specializes in large language models: AI trained to digest text from an enterprises' internal data or publicly available sources like the internet to understand how to process and respond to prompts with increasing sophistication.\n\nThe Cohere platform is available through API as a managed service, through platforms such as Amazon SageMaker and Google's Vertex AI. It can be used for tasks such as writing copy, moderating content, classifying data, and extracting information. It is cloud agnostic and not tied to a particular cloud service.\n\nCohere's generative AI technology is embedded into several Oracle products, and its chat capabilities are embedded into Salesforce products.", 'timestamp': '2024-03-11T12:19:29', 'title': 'Cohere - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/Cohere'}
#
#
#  Cohere specializes in large language models: AI trained to digest text from an enterprises' internal data or publicly available sources like the internet to understand how to process and respond to prompts with increasing sophistication.
#
# The Cohere platform is available through API as a managed service, through platforms such as Amazon SageMaker and Google's Vertex AI. It can be used for tasks such as writing copy, moderating content, classifying data, and extracting information. It is cloud agnostic and not tied to a particular cloud service.
#
# Cohere's generative AI technology is embedded into several Oracle products, and its chat capabilities are embedded into Salesforce products.
#
#
# ------------------------------
#
#
# {'id': 'web-search_5:0', 'snippet': 'Cohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.\n\nCohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.\n\nFundamental research lab\n\nWe work at the frontier of AI progress with the goal of solving cutting edge scientific problems. We see contributions to traditional conferences and publications in journals as an important part of our work, but also support efforts that go “beyond the research paper” and encourage scientific communication through different mediums.', 'timestamp': '2024-03-02T03:32:12', 'title': 'Research | Cohere For AI', 'url': 'https://cohere.com/research'}
#
#
# Cohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.
#
# Cohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.
#
# Fundamental research lab
#
# We work at the frontier of AI progress with the goal of solving cutting edge scientific problems. We see contributions to traditional conferences and publications in journals as an important part of our work, but also support efforts that go “beyond the research paper” and encourage scientific communication through different mediums.
#
#
# ------------------------------
#
#
# {'id': 'web-search_5:6', 'snippet': ' Today, Cohere is proud to reintroduce For AI as Cohere For AI, a dedicated research lab and community for exploring the unknown, together. Watch the C4AI history video here.\n\nDo you charge for your educational programs or community membership?\n\nWe do not charge for participating in any of our programs, and are committed to supporting educational outreach programs, which include compute resources and infrastructure needed to participate in machine learning research.\n\nare you hiring for research positions or interns?\n\nOur full list of positions are listed here.\n\nHow can I stay in touch?\n\nTo stay up to date on upcoming talks, sign up for our mailing list.', 'timestamp': '2024-03-02T03:32:12', 'title': 'Research | Cohere For AI', 'url': 'https://cohere.com/research'}
#
#
#  Today, Cohere is proud to reintroduce For AI as Cohere For AI, a dedicated research lab and community for exploring the unknown, together. Watch the C4AI history video here.
#
# Do you charge for your educational programs or community membership?
#
# We do not charge for participating in any of our programs, and are committed to supporting educational outreach programs, which include compute resources and infrastructure needed to participate in machine learning research.
#
# are you hiring for research positions or interns?
#
# Our full list of positions are listed here.
#
# How can I stay in touch?
#
# To stay up to date on upcoming talks, sign up for our mailing list.
#
#
# ------------------------------
#
#
# {'type': 'model_response', 'citations': [{'start': 12, 'end': 53, 'text': 'Canadian multinational technology company', 'document_ids': ['web-search_4:0']}, {'start': 74, 'end': 102, 'text': 'artificial intelligence (AI)', 'document_ids': ['web-search_4:0']}, {'start': 131, 'end': 212, 'text': 'developers to create and integrate large language models with their applications.', 'document_ids': ['web-search_9:0']}, {'start': 240, 'end': 244, 'text': '2019', 'document_ids': ['web-search_4:0']}, {'start': 248, 'end': 288, 'text': 'Aidan Gomez, Ivan Zhang, and Nick Frosst', 'document_ids': ['web-search_4:0']}, {'start': 292, 'end': 318, 'text': 'Toronto and San Francisco.', 'document_ids': ['web-search_4:0']}, {'start': 348, 'end': 375, 'text': 'AI solutions to enterprises', 'document_ids': ['web-search_4:0']}, {'start': 405, 'end': 408, 'text': 'API', 'document_ids': ['web-search_9:0', 'web-search_4:4']}, {'start': 424, 'end': 524, 'text': 'summarizing, classifying, and finding similarities in content, aka natural language processing (NLP)', 'document_ids': ['web-search_9:0']}, {'start': 552, 'end': 566, 'text': 'pre-built LLMs', 'document_ids': ['web-search_9:0']}, {'start': 579, 'end': 630, 'text': "customized based on the enterprise's training data.", 'document_ids': ['web-search_9:0']}, {'start': 670, 'end': 696, 'text': 'research lab and community', 'document_ids': ['web-search_5:0', 'web-search_5:6']}, {'start': 703, 'end': 716, 'text': 'Cohere For AI', 'document_ids': ['web-search_5:6']}, {'start': 735, 'end': 836, 'text': 'exploring machine learning problems and creating more points of entry into machine learning research.', 'document_ids': ['web-search_5:0']}, {'start': 861, 'end': 887, 'text': 'generative language models', 'document_ids': ['web-search_9:0']}, {'start': 959, 'end': 978, 'text': 'unfamiliar content.', 'document_ids': ['web-search_5:6']}], 'search_results': [{'search_query': {'text': 'What is cohere ai?', 'generation_id': '8d82e8a3-8c2c-45ea-ac3b-d3c9747a8ca9'}, 'document_ids': ['web-search_4:0', 'web-search_4:4', 'web-search_5:0', 'web-search_5:6', 'web-search_9:0'], 'connector': {'id': 'web-search'}}], 'search_queries': [{'text': 'What is cohere ai?', 'generation_id': '8d82e8a3-8c2c-45ea-ac3b-d3c9747a8ca9'}], 'token_count': {'prompt_tokens': 1611, 'response_tokens': 174, 'total_tokens': 1785, 'billed_tokens': 180}}
#
#
# Cohere is a Canadian multinational technology company that specializes in artificial intelligence (AI) and provides a platform for developers to create and integrate large language models with their applications. The company was founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst in Toronto and San Francisco.
#
# Cohere focuses on providing AI solutions to enterprises and offers a platform via an API for tasks like summarizing, classifying, and finding similarities in content, aka natural language processing (NLP). The company also provides pre-built LLMs that can be customized based on the enterprise's training data.
#
# Additionally, Cohere has a dedicated research lab and community named Cohere For AI, which focuses on exploring machine learning problems and creating more points of entry into machine learning research. Research topics include generative language models and investigating what happens when machine learning systems encounter unfamiliar content.
#
#
# ------------------------------

# %%
_pretty_print(await rag.aget_relevant_documents("What is cohere ai?"))  # async version
# Out:
# {'id': 'web-search_4:0', 'snippet': 'Cohere is a Canadian multinational technology company focused on artificial intelligence for the enterprise, specializing in large language models. Cohere was founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst, and is headquartered in Toronto and San Francisco, with offices in Palo Alto and London.\n\nIn 2017, a team of researchers at Google Brain, which included Aidan Gomez, published a paper called "Attention is All You Need," which introduced the transformer machine learning architecture, setting state-of-the-art performance on a variety of natural language processing tasks. In 2019, Gomez and Nick Frosst, another researcher at Google Brain, founded Cohere along with Ivan Zhang, with whom Gomez had done research at FOR.ai. All of the co-founders attended University of Toronto.', 'timestamp': '2024-03-11T12:19:29', 'title': 'Cohere - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/Cohere'}
#
#
# Cohere is a Canadian multinational technology company focused on artificial intelligence for the enterprise, specializing in large language models. Cohere was founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst, and is headquartered in Toronto and San Francisco, with offices in Palo Alto and London.
#
# In 2017, a team of researchers at Google Brain, which included Aidan Gomez, published a paper called "Attention is All You Need," which introduced the transformer machine learning architecture, setting state-of-the-art performance on a variety of natural language processing tasks. In 2019, Gomez and Nick Frosst, another researcher at Google Brain, founded Cohere along with Ivan Zhang, with whom Gomez had done research at FOR.ai. All of the co-founders attended University of Toronto.
#
#
# ------------------------------
#
#
# {'id': 'web-search_9:0', 'snippet': 'What does Cohere do?\n\nQuickly create and integrate AI large language models with your apps\n\nPhoto by Joshua J. Cotten on Unsplash\n\nCohere is an AI company specialising in large language models (LLMs), that offers a platform made available via an API enabling developers to:\n\nLeverage Cohere’s pre-built LLMs to perform common tasks on text input, such as: summarising, classification, and finding the similarities in content aka. natural language processing (NLP).\n\nCreate their own language models, based on the legwork Cohere has already done, that can be customised based on their own training data.\n\n🗝️ Key Concepts — Text Output vs. Embedding\n\nCohere provides access to two types of language model:\n\n📖 ➔ 💬 Generation Language Models: This takes text as an input and then spits out some different text, depending on the task the model is designed to achieve.', 'timestamp': '2024-03-07T21:43:27', 'title': 'What does Cohere do?. Quickly create and integrate AI large… | by Omer Mahmood | Geek Culture | Medium', 'url': 'https://medium.com/geekculture/what-does-cohere-do-cdadf6d70435'}
#
#
# What does Cohere do?
#
# Quickly create and integrate AI large language models with your apps
#
# Photo by Joshua J. Cotten on Unsplash
#
# Cohere is an AI company specialising in large language models (LLMs), that offers a platform made available via an API enabling developers to:
#
# Leverage Cohere’s pre-built LLMs to perform common tasks on text input, such as: summarising, classification, and finding the similarities in content aka. natural language processing (NLP).
#
# Create their own language models, based on the legwork Cohere has already done, that can be customised based on their own training data.
#
# 🗝️ Key Concepts — Text Output vs. Embedding
#
# Cohere provides access to two types of language model:
#
# 📖 ➔ 💬 Generation Language Models: This takes text as an input and then spits out some different text, depending on the task the model is designed to achieve.
#
#
# ------------------------------
#
#
# {'id': 'web-search_4:4', 'snippet': " Cohere specializes in large language models: AI trained to digest text from an enterprises' internal data or publicly available sources like the internet to understand how to process and respond to prompts with increasing sophistication.\n\nThe Cohere platform is available through API as a managed service, through platforms such as Amazon SageMaker and Google's Vertex AI. It can be used for tasks such as writing copy, moderating content, classifying data, and extracting information. It is cloud agnostic and not tied to a particular cloud service.\n\nCohere's generative AI technology is embedded into several Oracle products, and its chat capabilities are embedded into Salesforce products.", 'timestamp': '2024-03-11T12:19:29', 'title': 'Cohere - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/Cohere'}
#
#
#  Cohere specializes in large language models: AI trained to digest text from an enterprises' internal data or publicly available sources like the internet to understand how to process and respond to prompts with increasing sophistication.
#
# The Cohere platform is available through API as a managed service, through platforms such as Amazon SageMaker and Google's Vertex AI. It can be used for tasks such as writing copy, moderating content, classifying data, and extracting information. It is cloud agnostic and not tied to a particular cloud service.
#
# Cohere's generative AI technology is embedded into several Oracle products, and its chat capabilities are embedded into Salesforce products.
#
#
# ------------------------------
#
#
# {'id': 'web-search_5:0', 'snippet': 'Cohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.\n\nCohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.\n\nFundamental research lab\n\nWe work at the frontier of AI progress with the goal of solving cutting edge scientific problems. We see contributions to traditional conferences and publications in journals as an important part of our work, but also support efforts that go “beyond the research paper” and encourage scientific communication through different mediums.', 'timestamp': '2024-03-02T03:32:12', 'title': 'Research | Cohere For AI', 'url': 'https://cohere.com/research'}
#
#
# Cohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.
#
# Cohere For AI is a non-profit research lab that seeks to solve complex machine learning problems. We support fundamental research that explores the unknown, and are focused on creating more points of entry into machine learning research.
#
# Fundamental research lab
#
# We work at the frontier of AI progress with the goal of solving cutting edge scientific problems. We see contributions to traditional conferences and publications in journals as an important part of our work, but also support efforts that go “beyond the research paper” and encourage scientific communication through different mediums.
#
#
# ------------------------------
#
#
# {'id': 'web-search_5:6', 'snippet': ' Today, Cohere is proud to reintroduce For AI as Cohere For AI, a dedicated research lab and community for exploring the unknown, together. Watch the C4AI history video here.\n\nDo you charge for your educational programs or community membership?\n\nWe do not charge for participating in any of our programs, and are committed to supporting educational outreach programs, which include compute resources and infrastructure needed to participate in machine learning research.\n\nare you hiring for research positions or interns?\n\nOur full list of positions are listed here.\n\nHow can I stay in touch?\n\nTo stay up to date on upcoming talks, sign up for our mailing list.', 'timestamp': '2024-03-02T03:32:12', 'title': 'Research | Cohere For AI', 'url': 'https://cohere.com/research'}
#
#
#  Today, Cohere is proud to reintroduce For AI as Cohere For AI, a dedicated research lab and community for exploring the unknown, together. Watch the C4AI history video here.
#
# Do you charge for your educational programs or community membership?
#
# We do not charge for participating in any of our programs, and are committed to supporting educational outreach programs, which include compute resources and infrastructure needed to participate in machine learning research.
#
# are you hiring for research positions or interns?
#
# Our full list of positions are listed here.
#
# How can I stay in touch?
#
# To stay up to date on upcoming talks, sign up for our mailing list.
#
#
# ------------------------------
#
#
# {'type': 'model_response', 'citations': [{'start': 12, 'end': 53, 'text': 'Canadian multinational technology company', 'document_ids': ['web-search_4:0']}, {'start': 74, 'end': 102, 'text': 'artificial intelligence (AI)', 'document_ids': ['web-search_4:0', 'web-search_9:0', 'web-search_4:4']}, {'start': 120, 'end': 148, 'text': 'large language models (LLMs)', 'document_ids': ['web-search_4:0', 'web-search_9:0', 'web-search_4:4']}, {'start': 161, 'end': 271, 'text': 'founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst and is headquartered in Toronto and San Francisco.', 'document_ids': ['web-search_4:0']}, {'start': 326, 'end': 444, 'text': 'perform common text-based tasks, such as summarising, classification, and finding similarities in content through NLP.', 'document_ids': ['web-search_9:0']}, {'start': 489, 'end': 552, 'text': 'create custom language models based on their own training data.', 'document_ids': ['web-search_9:0']}, {'start': 596, 'end': 599, 'text': 'API', 'document_ids': ['web-search_9:0', 'web-search_4:4']}, {'start': 645, 'end': 685, 'text': "Amazon SageMaker and Google's Vertex AI.", 'document_ids': ['web-search_4:4']}, {'start': 754, 'end': 850, 'text': 'Cohere For AI, which is a non-profit research lab that solves complex machine learning problems.', 'document_ids': ['web-search_5:0', 'web-search_5:6']}, {'start': 867, 'end': 985, 'text': 'focus on fundamental research that explores the unknown and creating more entry points into machine learning research.', 'document_ids': ['web-search_5:0']}], 'search_results': [{'search_query': {'text': 'What is cohere ai?', 'generation_id': '4fe316db-3077-4a64-8b55-ba7ef7b6e615'}, 'document_ids': ['web-search_4:0', 'web-search_4:4', 'web-search_5:0', 'web-search_5:6', 'web-search_9:0'], 'connector': {'id': 'web-search'}}], 'search_queries': [{'text': 'What is cohere ai?', 'generation_id': '4fe316db-3077-4a64-8b55-ba7ef7b6e615'}], 'token_count': {'prompt_tokens': 1611, 'response_tokens': 186, 'total_tokens': 1797, 'billed_tokens': 192}}
#
#
# Cohere is a Canadian multinational technology company that specializes in artificial intelligence (AI) and specifically large language models (LLMs). Cohere was founded in 2019 by Aidan Gomez, Ivan Zhang, and Nick Frosst and is headquartered in Toronto and San Francisco.
#
# Cohere offers a platform that enables developers to perform common text-based tasks, such as summarising, classification, and finding similarities in content through NLP. Through their platform, developers can also create custom language models based on their own training data.
#
# The Cohere platform is available through API and can be integrated with platforms such as Amazon SageMaker and Google's Vertex AI.
#
# Aside from the commercial/business aspect of Cohere, there is also Cohere For AI, which is a non-profit research lab that solves complex machine learning problems. They explicitly focus on fundamental research that explores the unknown and creating more entry points into machine learning research.
#
#
# ------------------------------

# %%
docs = rag.get_relevant_documents(
    "Does langchain support cohere RAG?",
    source_documents=[
        Document(page_content="Langchain supports cohere RAG!"),
        Document(page_content="The sky is blue!"),
    ],
)
_pretty_print(docs)
# Out:
# {'id': 'doc-0', 'snippet': 'Langchain supports cohere RAG!'}
#
#
# Langchain supports cohere RAG!
#
#
# ------------------------------
#
#
# {'type': 'model_response', 'citations': [{'start': 0, 'end': 4, 'text': 'Yay!', 'document_ids': ['doc-0']}], 'search_results': None, 'search_queries': [{'text': 'langchain cohere RAG', 'generation_id': 'b9d6884c-4d56-427c-9357-c3adde1d031b'}], 'token_count': {'prompt_tokens': 607, 'response_tokens': 17, 'total_tokens': 624, 'billed_tokens': 26}}
#
#
# Yay! LangChain supports Cohere's Responsible AI Guideline (RAG)!
#
#
# ------------------------------
