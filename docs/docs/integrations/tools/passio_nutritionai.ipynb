# %% [markdown]
# # Passio Nutrition AI Food Search
#
# >[Passio Nutrition AI](https://www.passio.ai/nutrition-ai), commonly referred to as `NutritionAI`.

# %% [markdown]
# This notebook goes over how to use the Passio NutritionAI food-search component.
#
# 1. Get an API key [here](https://passio.gitbook.io/nutrition-api/).
# 2. Place the key into the environment variable below.
# 3. Run All

# %%
import os

os.environ["NUTRITIONAI_SUBSCRIPTION_KEY"] = "<key>"
os.environ["NUTRITIONAI_API_URL"] = "https://api.passiolife.com/v2/products/napi/food/search/advanced"

# %%
from langchain_community.utilities import NutritionAIAPI
from langchain_community.utilities.passio_nutritionai import NutritionAIAPI

# %%
search = NutritionAIAPI()

# %%
tool.run("chicken tikka masala")
# Out:
# {'results': [{'type': 'reference',
#    'displayName': 'Chicken Tikka Masala',
#    'stemmedDisplayName': '',
#    'shortName': '',
#    'longName': 'Chicken Tikka Masala',
#    'scoredName': 'Chicken Tikka Masala',
#    'score': 1,
#    'displayNameScore': 1,
#    'brandName': '',
#    'iconId': '',
#    'labelId': '',
#    'synonymId': '',
#    'recipeId': '',
#    'referenceId': 'openfood0085239308349',
#    'resultId': 'openfood0085239308349',
#    'nutritionPreview': {'portion': {'weight': {'unit': 'g', 'value': 100},
#      'name': '',
#      'quantity': 1,
#      'suggestedQuantity': [1]},
#     'calories': 142.8571014404297}},
#   {'type': 'reference',
#    'displayName': 'Chicken Tikka Masala',
#    'stemmedDisplayName': '',
#    'shortName': '',
#    'longName': 'Chicken Tikka Masala',
#    'scoredName': 'Chicken Tikka Masala',
#    'score': 0.95,
#    'displayNameScore': 0.95,
#    'brandName': 'Target Stores',
#    'iconId': '',
#    'labelId': '',
#    'synonymId': '',
# ...
