# %% [markdown]
# # SEC API Tool
#
# ## Overview
#
# The SEC API Tool provides access to SEC EDGAR filings data. It allows you to:
# - Search full text content of SEC filings
# - Retrieve company filings by ticker symbol
# - Filter by form types (10-K, 10-Q, 8-K) and date ranges
#
# ## Setup
#
# First, you'll need to get an API key from SEC API. Visit [sec-api.io](https://sec-api.io) to sign up.
#
# ## Instantiation

# %%
import requests
from langchain_community.tools.sec_api.tool import SECAPITool
from langchain_community.utilities.secapi import CustomSECAPI

api_key = "YOUR_API_KEY"
tool = SECAPITool(api_key=api_key)

# %%
# result = tool.full_text_search("substantial doubt", form_types=["10-K"])
result = tool.filing_search("AAPL", form_type="10-K")
result
# Out:
# {'total': {'value': 348, 'relation': 'eq'},
#  'query': {'from': 0, 'size': 50},
#  'filings': [{'ticker': 'AAPL',
#    'formType': '10-K',
#    'accessionNo': '0000320193-24-000123',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt',
#    'filedAt': '2024-11-01T06:01:36-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '1503780',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000123/aapl-20240928.htm',
#      'description': '10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '120785',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit4109282024.htm',
#      'description': 'EX-4.1',
#      'type': 'EX-4.1'},
#     {'sequence': '3',
#      'size': '56948',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10199282024.htm',
#      'description': 'EX-10.19',
#      'type': 'EX-10.19'},
#     {'sequence': '4',
#      'size': '74591',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10209282024.htm',
#      'description': 'EX-10.20',
#      'type': 'EX-10.20'},
#     {'sequence': '5',
#      'size': '60845',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10219282024.htm',
#      'description': 'EX-10.21',
#      'type': 'EX-10.21'},
#     {'sequence': '6',
#      'size': '75240',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit10229282024.htm',
#      'description': 'EX-10.22',
#      'type': 'EX-10.22'},
#     {'sequence': '7',
#      'size': '44108',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit1919282024.htm',
#      'description': 'EX-19.1',
#      'type': 'EX-19.1'},
#     {'sequence': '8',
#      'size': '11229',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit21109282024.htm',
#      'description': 'EX-21.1',
#      'type': 'EX-21.1'},
#     {'sequence': '9',
#      'size': '5018',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit23109282024.htm',
#      'description': 'EX-23.1',
#      'type': 'EX-23.1'},
#     {'sequence': '10',
#      'size': '10508',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31109282024.htm',
#      'description': 'EX-31.1',
#      'type': 'EX-31.1'},
#     {'sequence': '11',
#      'size': '10544',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit31209282024.htm',
#      'description': 'EX-31.2',
#      'type': 'EX-31.2'},
#     {'sequence': '12',
#      'size': '8357',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit32109282024.htm',
#      'description': 'EX-32.1',
#      'type': 'EX-32.1'},
#     {'sequence': '13',
#      'size': '13555',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/a10-kexhibit97109282024.htm',
#      'description': 'EX-97.1',
#      'type': 'EX-97.1'},
#     {'sequence': '19',
#      'size': '10963',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '20',
#      'size': '154498',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_g2.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '21',
#      'size': '2374',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_0.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '22',
#      'size': '2563',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/image_01.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '9759333',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-09-28',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '10-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241416806',
#      'undefined': '06 Technology)'}],
#    'id': 'de98dc75c98b80c2bbfeb8d07503354b',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/0000320193-24-000123-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '14',
#      'size': '58200',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '15',
#      'size': '150261',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '16',
#      'size': '232678',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '17',
#      'size': '779708',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '18',
#      'size': '509625',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '106',
#      'size': '1355849',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000123/aapl-20240928_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0000320193-24-000120',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031.htm',
#    'description': 'Form 8-K - Current report - Item 2.02 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/0000320193-24-000120.txt',
#    'filedAt': '2024-10-31T16:30:25-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '40452',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000120/aapl-20241031.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '198391',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/a8-kex991q4202409282024.htm',
#      'description': 'EX-99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '7',
#      'size': '1264',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '469716',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/0000320193-24-000120.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-10-31',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241415685',
#      'undefined': '06 Technology)'}],
#    'id': '80bcd2cf5cca7939373820f1aa29e56b',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 2.02: Results of Operations and Financial Condition',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/0000320193-24-000120-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '4071',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '19066',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '5',
#      'size': '36338',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '6',
#      'size': '20213',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '18',
#      'size': '9190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000120/aapl-20241031_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0001140361-24-040659',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/ef20035718_8k.htm',
#    'description': 'Form 8-K - Current report - Item 7.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/0001140361-24-040659.txt',
#    'filedAt': '2024-09-10T09:06:34-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '48733',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000114036124040659/ef20035718_8k.htm',
#      'description': 'FORM 8-K',
#      'type': '8-K'},
#     {'sequence': '6',
#      'size': '371118',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/logo_apple.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '1248169',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/0001140361-24-040659.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-09-10',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241288853',
#      'undefined': '06 Technology)'}],
#    'id': 'f8218a4e824702a2c5243aa9cca3fc46',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 7.01: Regulation FD Disclosure'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/0001140361-24-040659-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '2',
#      'size': '5738',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/aapl-20240910.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '3',
#      'size': '19726',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/aapl-20240910_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '4',
#      'size': '29289',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/aapl-20240910_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '5',
#      'size': '21642',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/aapl-20240910_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '18',
#      'size': '13701',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124040659/ef20035718_8k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0001140361-24-038601',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/ny20033611x3_8k.htm',
#    'description': 'Form 8-K - Current report - Item 5.02',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/0001140361-24-038601.txt',
#    'filedAt': '2024-08-26T17:20:33-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '44448',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000114036124038601/ny20033611x3_8k.htm',
#      'description': 'FORM 8-K',
#      'type': '8-K'},
#     {'sequence': '6',
#      'size': '371118',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/logo_apple.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '1242096',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/0001140361-24-038601.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-08-26',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241242410',
#      'undefined': '06 Technology)'}],
#    'id': 'b767d162ca1d2d24cd7b17f8123d8b29',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 5.02: Departure of Directors or Certain Officers; Election of Directors; Appointment of Certain Officers: Compensatory Arrangements of Certain Officers'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/0001140361-24-038601-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '2',
#      'size': '5738',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/aapl-20240826.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '3',
#      'size': '19726',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/aapl-20240826_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '4',
#      'size': '29289',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/aapl-20240826_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '5',
#      'size': '21642',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/aapl-20240826_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '18',
#      'size': '13701',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038601/ny20033611x3_8k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0001140361-24-038403',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/ny20033611x2_8k.htm',
#    'description': 'Form 8-K - Current report - Item 5.03 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/0001140361-24-038403.txt',
#    'filedAt': '2024-08-23T16:30:44-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '51247',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000114036124038403/ny20033611x2_8k.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '276562',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/ny20033611x2_ex3-2.htm',
#      'description': 'EXHIBIT 3.2',
#      'type': 'EX-3.2'},
#     {'sequence': '7',
#      'size': '197243',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/ny20033611x2_8kimg001.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '1131218',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/0001140361-24-038403.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-08-20',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241236709',
#      'undefined': '06 Technology)'}],
#    'id': 'f6bda104136eed2a5b99794983200adb',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 5.03: Amendments to Articles of Incorporation or Bylaws; Change in Fiscal Year',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/0001140361-24-038403-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '5738',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/aapl-20240820.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '20197',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/aapl-20240820_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '5',
#      'size': '30014',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/aapl-20240820_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '6',
#      'size': '22170',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/aapl-20240820_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '19',
#      'size': '13862',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124038403/ny20033611x2_8k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '10-Q',
#    'accessionNo': '0000320193-24-000081',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629.htm',
#    'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081.txt',
#    'filedAt': '2024-08-01T18:03:34-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '889136',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000081/aapl-20240629.htm',
#      'description': '10-Q',
#      'type': '10-Q'},
#     {'sequence': '2',
#      'size': '10527',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit31106292024.htm',
#      'description': 'EX-31.1',
#      'type': 'EX-31.1'},
#     {'sequence': '3',
#      'size': '10544',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit31206292024.htm',
#      'description': 'EX-31.2',
#      'type': 'EX-31.2'},
#     {'sequence': '4',
#      'size': '8338',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/a10-qexhibit32106292024.htm',
#      'description': 'EX-32.1',
#      'type': 'EX-32.1'},
#     {'sequence': '10',
#      'size': '10963',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '5372771',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-06-29',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '10-Q',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241168182',
#      'undefined': '06 Technology)'}],
#    'id': 'cf8f0e4b9c36b768706ac2f63dfceb84',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/0000320193-24-000081-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '5',
#      'size': '34455',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '6',
#      'size': '79020',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '7',
#      'size': '155463',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '8',
#      'size': '496189',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '9',
#      'size': '320486',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '69',
#      'size': '786618',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000081/aapl-20240629_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0000320193-24-000080',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801.htm',
#    'description': 'Form 8-K - Current report - Item 2.02 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/0000320193-24-000080.txt',
#    'filedAt': '2024-08-01T16:30:26-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '41210',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000080/aapl-20240801.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '168416',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/a8-kex991q3202406292024.htm',
#      'description': 'EX-99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '7',
#      'size': '1264',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '437770',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/0000320193-24-000080.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-08-01',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '241167232',
#      'undefined': '06 Technology)'}],
#    'id': '7edffec90b175b20c2d1357b30817be9',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 2.02: Results of Operations and Financial Condition',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/0000320193-24-000080-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '4190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '19066',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '5',
#      'size': '36338',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '6',
#      'size': '20213',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '18',
#      'size': '9190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000080/aapl-20240801_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0001140361-24-024352',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/ef20028273_8k.htm',
#    'description': 'Form 8-K - Current report - Item 7.01 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/0001140361-24-024352.txt',
#    'filedAt': '2024-05-03T16:35:42-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '39213',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000114036124024352/ef20028273_8k.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '129572',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/ef20028273_ex99-1.htm',
#      'description': 'EXHIBIT 99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '3',
#      'size': '624489',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/ef20028273_ex99-2.htm',
#      'description': 'EXHIBIT 99.2',
#      'type': 'EX-99.2'},
#     {'sequence': '8',
#      'size': '1160',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/image01.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '1131483',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/0001140361-24-024352.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-05-03',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '24913807',
#      'undefined': '06 Technology)'}],
#    'id': 'a5825fc457f7aa747c45c1d861cc3a23',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 7.01: Regulation FD Disclosure',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/0001140361-24-024352-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '4',
#      'size': '5738',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/aapl-20240503.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '5',
#      'size': '18205',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/aapl-20240503_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '6',
#      'size': '32164',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/aapl-20240503_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '7',
#      'size': '20544',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/aapl-20240503_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '20',
#      'size': '13981',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124024352/ef20028273_8k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '10-Q',
#    'accessionNo': '0000320193-24-000069',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330.htm',
#    'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069.txt',
#    'filedAt': '2024-05-02T18:04:25-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '884846',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000069/aapl-20240330.htm',
#      'description': '10-Q',
#      'type': '10-Q'},
#     {'sequence': '2',
#      'size': '10524',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit31103302024.htm',
#      'description': 'EX-31.1',
#      'type': 'EX-31.1'},
#     {'sequence': '3',
#      'size': '10541',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit31203302024.htm',
#      'description': 'EX-31.2',
#      'type': 'EX-31.2'},
#     {'sequence': '4',
#      'size': '8334',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/a10-qexhibit32103302024.htm',
#      'description': 'EX-32.1',
#      'type': 'EX-32.1'},
#     {'sequence': '10',
#      'size': '10963',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '5284139',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-03-30',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '10-Q',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '24910117',
#      'undefined': '06 Technology)'}],
#    'id': '6c0b495bc8a221cf32387c0123aeee5a',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/0000320193-24-000069-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '5',
#      'size': '32774',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '6',
#      'size': '79020',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '7',
#      'size': '150723',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '8',
#      'size': '486518',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '9',
#      'size': '313675',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '68',
#      'size': '780999',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000069/aapl-20240330_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0000320193-24-000067',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502.htm',
#    'description': 'Form 8-K - Current report - Item 2.02 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/0000320193-24-000067.txt',
#    'filedAt': '2024-05-02T16:30:34-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '40428',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000067/aapl-20240502.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '167761',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/a8-kex991q2202403302024.htm',
#      'description': 'EX-99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '7',
#      'size': '1264',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '436360',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/0000320193-24-000067.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-05-02',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '24908945',
#      'undefined': '06 Technology)'}],
#    'id': '3f704fba340527cca1ba5751cff35a94',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 2.02: Results of Operations and Financial Condition',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/0000320193-24-000067-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '4190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '19066',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '5',
#      'size': '36338',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '6',
#      'size': '20213',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '19',
#      'size': '9190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000067/aapl-20240502_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0001140361-24-010155',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/ny20022580x1_8k.htm',
#    'description': 'Form 8-K - Current report - Item 5.07',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/0001140361-24-010155.txt',
#    'filedAt': '2024-02-28T17:09:05-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '88596',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000114036124010155/ny20022580x1_8k.htm',
#      'description': 'FORM 8-K',
#      'type': '8-K'},
#     {'sequence': '6',
#      'size': '275763',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/ny20022580x1_image01.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '859597',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/0001140361-24-010155.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-02-28',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '24696744'}],
#    'id': '32215f8891c466c82c726940b7250445',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 5.07: Submission of Matters to a Vote of Security Holders'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/0001140361-24-010155-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '2',
#      'size': '5738',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/aapl-20240228.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '3',
#      'size': '18205',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/aapl-20240228_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '4',
#      'size': '27827',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/aapl-20240228_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '5',
#      'size': '20504',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/aapl-20240228_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '18',
#      'size': '13981',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000114036124010155/ny20022580x1_8k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '10-Q',
#    'accessionNo': '0000320193-24-000006',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230.htm',
#    'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006.txt',
#    'filedAt': '2024-02-01T18:03:38-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '732173',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000006/aapl-20231230.htm',
#      'description': '10-Q',
#      'type': '10-Q'},
#     {'sequence': '2',
#      'size': '10529',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit31112302023.htm',
#      'description': 'EX-31.1',
#      'type': 'EX-31.1'},
#     {'sequence': '3',
#      'size': '10546',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit31212302023.htm',
#      'description': 'EX-31.2',
#      'type': 'EX-31.2'},
#     {'sequence': '4',
#      'size': '8350',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/a10-qexhibit32112302023.htm',
#      'description': 'EX-32.1',
#      'type': 'EX-32.1'},
#     {'sequence': '10',
#      'size': '10963',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '4984121',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2023-12-30',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '10-Q',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '24588164'}],
#    'id': '89bd0dd65bb737638cd64a2f597b5155',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/0000320193-24-000006-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '5',
#      'size': '33359',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '6',
#      'size': '79020',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '7',
#      'size': '151992',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '8',
#      'size': '534119',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '9',
#      'size': '315230',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '67',
#      'size': '666167',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000006/aapl-20231230_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0000320193-24-000005',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201.htm',
#    'description': 'Form 8-K - Current report - Item 2.02 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/0000320193-24-000005.txt',
#    'filedAt': '2024-02-01T16:30:30-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '40631',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019324000005/aapl-20240201.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '140647',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/a8-kex991q1202412302023.htm',
#      'description': 'EX-99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '7',
#      'size': '1264',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '412459',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/0000320193-24-000005.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2024-02-01',
#    'entities': [{'fiscalYearEnd': '0928',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '24587382'}],
#    'id': '87e375b12eeb9857f09e3b58a526c18f',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 2.02: Results of Operations and Financial Condition',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/0000320193-24-000005-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '4190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '19066',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '5',
#      'size': '40356',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '6',
#      'size': '20213',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '18',
#      'size': '9190',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019324000005/aapl-20240201_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
# ...
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000010/aapl-20201226_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '13',
#      'size': '1436214',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000010/aapl-20201226_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0000320193-21-000009',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019321000009/aapl-20210127.htm',
#    'description': 'Form 8-K - Current report - Item 2.02 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/0000320193-21-000009.txt',
#    'filedAt': '2021-01-27T16:30:35-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '64252',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019321000009/aapl-20210127.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '148887',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/a8-kex991q1202112262020.htm',
#      'description': 'EX-99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '8',
#      'size': '1264',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '486776',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/0000320193-21-000009.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2021-01-27',
#    'entities': [{'fiscalYearEnd': '0925',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '21560158'}],
#    'id': 'c6d3fcccc04201f8da2566322d04b6d7',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 2.02: Results of Operations and Financial Condition',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/0000320193-21-000009-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '4842',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '716',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '5',
#      'size': '20206',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '6',
#      'size': '43107',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '7',
#      'size': '21426',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '9',
#      'size': '30963',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019321000009/aapl-20210127_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0001193125-21-001982',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000119312521001982/d29637d8k.htm',
#    'description': 'Form 8-K - Current report - Item 5.02',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/0001193125-21-001982.txt',
#    'filedAt': '2021-01-05T16:32:16-05:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '41180',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000119312521001982/d29637d8k.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '6',
#      'size': '18443',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/g29637g56j44.jpg',
#      'description': 'GRAPHIC',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '290029',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/0001193125-21-001982.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2020-12-29',
#    'entities': [{'fiscalYearEnd': '0925',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '21506117'}],
#    'id': 'ad063d587d19ced239022a180f2b1488',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 5.02: Departure of Directors or Certain Officers; Election of Directors; Appointment of Certain Officers: Compensatory Arrangements of Certain Officers'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/0001193125-21-001982-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '2',
#      'size': '5357',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/aapl-20201229.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA',
#      'type': 'EX-101.SCH'},
#     {'sequence': '3',
#      'size': '16861',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/aapl-20201229_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE',
#      'type': 'EX-101.DEF'},
#     {'sequence': '4',
#      'size': '28987',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/aapl-20201229_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE',
#      'type': 'EX-101.LAB'},
#     {'sequence': '5',
#      'size': '18211',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/aapl-20201229_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE',
#      'type': 'EX-101.PRE'},
#     {'sequence': '7',
#      'size': '15020',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000119312521001982/d29637d8k_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '10-K',
#    'accessionNo': '0000320193-20-000096',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096.txt',
#    'filedAt': '2020-10-29T18:06:25-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '2467306',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm',
#      'description': '10-K',
#      'type': '10-K'},
#     {'sequence': '2',
#      'size': '123356',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit419262020.htm',
#      'description': 'EX-4.1',
#      'type': 'EX-4.1'},
#     {'sequence': '3',
#      'size': '56918',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit10169262020.htm',
#      'description': 'EX-10.16',
#      'type': 'EX-10.16'},
#     {'sequence': '4',
#      'size': '74685',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit10179262020.htm',
#      'description': 'EX-10.17',
#      'type': 'EX-10.17'},
#     {'sequence': '5',
#      'size': '9230',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit2119262020.htm',
#      'description': 'EX-21.1',
#      'type': 'EX-21.1'},
#     {'sequence': '6',
#      'size': '5991',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit2319262020.htm',
#      'description': 'EX-23.1',
#      'type': 'EX-23.1'},
#     {'sequence': '7',
#      'size': '10582',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit3119262020.htm',
#      'description': 'EX-31.1',
#      'type': 'EX-31.1'},
#     {'sequence': '8',
#      'size': '10618',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit3129262020.htm',
#      'description': 'EX-31.2',
#      'type': 'EX-31.2'},
#     {'sequence': '9',
#      'size': '8476',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/a10-kexhibit3219262020.htm',
#      'description': 'EX-32.1',
#      'type': 'EX-32.1'},
#     {'sequence': '15',
#      'size': '10963',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '16',
#      'size': '169473',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_g2.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '12502600',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2020-09-26',
#    'entities': [{'fiscalYearEnd': '0926',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '0000320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '10-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '201273977'}],
#    'id': '96618433ccb8db908723fb09aa081a34',
#    'seriesAndClassesContractsInformation': [],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '10',
#      'size': '64821',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '11',
#      'size': '159538',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '12',
#      'size': '348789',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '13',
#      'size': '900558',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '14',
#      'size': '574436',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '17',
#      'size': '2405367',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]},
#   {'ticker': 'AAPL',
#    'formType': '8-K',
#    'accessionNo': '0000320193-20-000094',
#    'cik': '320193',
#    'companyNameLong': 'Apple Inc. (Filer)',
#    'effectivenessDate': '2020-10-29',
#    'companyName': 'Apple Inc.',
#    'linkToFilingDetails': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019320000094/aapl-20201029.htm',
#    'description': 'Form 8-K - Current report - Item 2.02 Item 9.01',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/0000320193-20-000094.txt',
#    'filedAt': '2020-10-29T16:30:32-04:00',
#    'documentFormatFiles': [{'sequence': '1',
#      'size': '64174',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000032019320000094/aapl-20201029.htm',
#      'description': '8-K',
#      'type': '8-K'},
#     {'sequence': '2',
#      'size': '178058',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/a8-kex991q420209262020.htm',
#      'description': 'EX-99.1',
#      'type': 'EX-99.1'},
#     {'sequence': '8',
#      'size': '1264',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029_g1.jpg',
#      'type': 'GRAPHIC'},
#     {'sequence': '\xa0',
#      'size': '516927',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/0000320193-20-000094.txt',
#      'description': 'Complete submission text file',
#      'type': '\xa0'}],
#    'periodOfReport': '2020-10-29',
#    'entities': [{'fiscalYearEnd': '0926',
#      'stateOfIncorporation': 'CA',
#      'act': '34',
#      'cik': '320193',
#      'fileNo': '001-36743',
#      'irsNo': '942404110',
#      'companyName': 'Apple Inc. (Filer)',
#      'type': '8-K',
#      'sic': '3571 Electronic Computers',
#      'filmNo': '201273047'}],
#    'id': '09c2512e36e5ba560be23bf15564e219',
#    'seriesAndClassesContractsInformation': [],
#    'items': ['Item 2.02: Results of Operations and Financial Condition',
#     'Item 9.01: Financial Statements and Exhibits'],
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/320193/0000320193-20-000094-index.htm',
#    'linkToXbrl': '',
#    'dataFiles': [{'sequence': '3',
#      'size': '4842',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029.xsd',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'type': 'EX-101.SCH'},
#     {'sequence': '4',
#      'size': '716',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029_cal.xml',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'type': 'EX-101.CAL'},
#     {'sequence': '5',
#      'size': '20206',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029_def.xml',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'type': 'EX-101.DEF'},
#     {'sequence': '6',
#      'size': '43107',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029_lab.xml',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'type': 'EX-101.LAB'},
#     {'sequence': '7',
#      'size': '21426',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029_pre.xml',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'type': 'EX-101.PRE'},
#     {'sequence': '9',
#      'size': '30972',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000094/aapl-20201029_htm.xml',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'type': 'XML'}]}]}

# %% [markdown]
# ## Invocation
#
# The tool provides two main methods:
# - `filing_search`: Search for company filings by ticker
# - `full_text_search`: Search through filing content
#
# ## Chaining
#
# The SEC API Tool can be used in chains to analyze SEC filings data.

# %% [markdown]
# ## API reference
#
# For more details, see the [API reference](https://python.langchain.com/api_reference/tools/langchain_community.tools.sec_api.tool.SECAPITool.html).
