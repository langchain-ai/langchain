# %% [markdown]
# # FireCrawl
#
# [FireCrawl](https://firecrawl.dev/?ref=langchain) crawls and convert any website into LLM-ready data. It crawls all accessible subpages and give you clean markdown and metadata for each. No sitemap required.
#
# FireCrawl handles complex tasks such as reverse proxies, caching, rate limits, and content blocked by JavaScript. Built by the [mendable.ai](https://mendable.ai) team.

# %% [markdown]
# ## Setup

# %%
pip install firecrawl-py

# %% [markdown]
# ## Usage

# %% [markdown]
# You will need to get your own API key. See https://firecrawl.dev

# %%
from document_loaders.firecrawl import FireCrawlLoader

# %%
loader = FireCrawlLoader(
    api_key="YOUR_API_KEY", url="https://firecrawl.dev", mode="scrape"
)

# %%
docs = loader.load()

# %%
docs
# Out:
# [Document(page_content='Introducing [LLM Extraction!](https://firecrawl.dev/playground?mode=llm-extract)\n Convert any web page into structured data using LLMs\n\n![Slack Logo](/images/slack_logo_icon.png)\n\nNew message in: #coach-gtm\n==========================\n\n@CoachGTM: Your meeting prep for Pied Piper < > WindFlow Dynamics is ready! Meeting starts in 30 minutes\n\n[🦜🔗 Check out our LangChain integration](https://python.langchain.com/docs/integrations/document_loaders/firecrawl/)\n\nTurn websites into  \n_LLM-ready_ data\n=====================================\n\nCrawl and convert any website into clean markdown or structured data\n\nTry now 300 free creditsNo credit card required\n\nA product by\n\n[![Mendable Logo](/images/mendable_logo_transparent.png)Mendable](https://mendable.ai)\n\n![Mendable Website Image](/mendable-hero-8.webp)\n\nCrawl, Capture, Clean\n---------------------\n\nWe crawl all accessible subpages and give you clean markdown for each. No sitemap required.\n\n    \n      [\\\n        {\\\n          "url": "https://www.mendable.ai/",\\\n          "markdown": "## Welcome to Mendable\\\n            Mendable empowers teams with AI-driven solutions - \\\n            streamlining sales and support."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/features",\\\n          "markdown": "## Features\\\n            Discover how Mendable\'s cutting-edge features can \\\n            transform your business operations."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/pricing",\\\n          "markdown": "## Pricing Plans\\\n            Choose the perfect plan that fits your business needs."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/about",\\\n          "markdown": "## About Us\\\n            Learn more about Mendable\'s mission and the \\\n            team behind our innovative platform."\\\n        }\\\n      ]\n      \n\nNote: The markdown has been edited for display purposes.\n\nWe handle the hard stuff\n------------------------\n\nProxies, caching, rate limits, js-blocked content and more...\n\n#### Crawling\n\nFireCrawl crawls all accessible subpages, even without a sitemap.\n\n#### Dynamic content\n\nFireCrawl gathers data even if a website uses javascript to render content.\n\n#### To Markdown\n\nFireCrawl returns clean, well formatted markdown - ready for use in LLM applications\n\n#### Crawling Orchestration\n\nFireCrawl orchestrates the crawling process in parallel for the fastest results.\n\n#### Caching\n\nFireCrawl caches content, so you don\'t have to wait for a full scrape unless new content exists.\n\n#### Built for AI\n\nBuilt by LLM engineers, for LLM engineers. Giving you clean data the way you want it.\n\nOur wall of love\n\nDon\'t take our word for it\n--------------------------\n\n![Greg Kamradt](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-02.0afeb750.jpg&w=96&q=75)\n\nGreg Kamradt\n\n[@GregKamradt](https://twitter.com/GregKamradt/status/1780300642197840307)\n\nLLM structured data via API, handling requests, cleaning, and crawling. Enjoyed the early preview.\n\n![Amit Naik](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-03.ff5dbe11.jpg&w=96&q=75)\n\nAmit Naik\n\n[@suprgeek](https://twitter.com/suprgeek/status/1780338213351035254)\n\n#llm success with RAG relies on Retrieval. Firecrawl by @mendableai structures web content for processing. 👏\n\n![Jerry Liu](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-04.76bef0df.jpg&w=96&q=75)\n\nJerry Liu\n\n[@jerryjliu0](https://twitter.com/jerryjliu0/status/1781122933349572772)\n\nFirecrawl is awesome 🔥 Turns web pages into structured markdown for LLM apps, thanks to @mendableai.\n\n![Bardia Pourvakil](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-01.025350bc.jpeg&w=96&q=75)\n\nBardia Pourvakil\n\n[@thepericulum](https://twitter.com/thepericulum/status/1781397799487078874)\n\nThese guys ship. I wanted types for their node SDK, and less tha ...
#  Document(page_content='\n\nYou signed in with another tab or window. Reload to refresh your session. You signed out in another tab or window. Reload to refresh your session. You switched accounts on another tab or window. Reload to refresh your session. Dismiss alert\n\n/ **[firecrawl](/mendableai/firecrawl)** Public\n\n*   [Notifications](/login?return_to=%2Fmendableai%2Ffirecrawl)\n    \n*   [Fork 242](/login?return_to=%2Fmendableai%2Ffirecrawl)\n    \n*   [Star 2.9k](/login?return_to=%2Fmendableai%2Ffirecrawl)\n    \n\n🔥 Turn entire websites into LLM-ready markdown\n\n[firecrawl.dev](https://firecrawl.dev "https://firecrawl.dev")\n\n### License\n\n[AGPL-3.0 license](/mendableai/firecrawl/blob/main/LICENSE)\n\n[2.9k stars](/mendableai/firecrawl/stargazers)\n [242 forks](/mendableai/firecrawl/forks)\n [Branches](/mendableai/firecrawl/branches)\n [Tags](/mendableai/firecrawl/tags)\n [Activity](/mendableai/firecrawl/activity)\n\n[Star](/login?return_to=%2Fmendableai%2Ffirecrawl)\n\n[Notifications](/login?return_to=%2Fmendableai%2Ffirecrawl)\n\nmendableai/firecrawl\n====================\n\nThis commit does not belong to any branch on this repository, and may belong to a fork outside of the repository.\n\n\xa0main\n\n[Branches](/mendableai/firecrawl/branches)\n[Tags](/mendableai/firecrawl/tags)\n\n[](/mendableai/firecrawl/branches)\n[](/mendableai/firecrawl/tags)\n\nGo to file\n\nCode\n\nFolders and files\n-----------------\n\n| Name |     | Name | Last commit message | Last commit date |\n| --- | --- | --- | --- |\n| Latest commit<br>-------------<br><br>History<br>-------<br><br>[394 Commits](/mendableai/firecrawl/commits/main/)<br><br>[](/mendableai/firecrawl/commits/main/) |     |     |\n| ### <br><br>[.github/workflows](/mendableai/firecrawl/tree/main/.github/workflows "This path skips through empty directories") |     | ### <br><br>[.github/workflows](/mendableai/firecrawl/tree/main/.github/workflows "This path skips through empty directories") |     |     |\n| ### <br><br>[apps](/mendableai/firecrawl/tree/main/apps "apps") |     | ### <br><br>[apps](/mendableai/firecrawl/tree/main/apps "apps") |     |     |\n| ### <br><br>[tutorials](/mendableai/firecrawl/tree/main/tutorials "tutorials") |     | ### <br><br>[tutorials](/mendableai/firecrawl/tree/main/tutorials "tutorials") |     |     |\n| ### <br><br>[.gitattributes](/mendableai/firecrawl/blob/main/.gitattributes ".gitattributes") |     | ### <br><br>[.gitattributes](/mendableai/firecrawl/blob/main/.gitattributes ".gitattributes") |     |     |\n| ### <br><br>[.gitignore](/mendableai/firecrawl/blob/main/.gitignore ".gitignore") |     | ### <br><br>[.gitignore](/mendableai/firecrawl/blob/main/.gitignore ".gitignore") |     |     |\n| ### <br><br>[CONTRIBUTING.md](/mendableai/firecrawl/blob/main/CONTRIBUTING.md "CONTRIBUTING.md") |     | ### <br><br>[CONTRIBUTING.md](/mendableai/firecrawl/blob/main/CONTRIBUTING.md "CONTRIBUTING.md") |     |     |\n| ### <br><br>[LICENSE](/mendableai/firecrawl/blob/main/LICENSE "LICENSE") |     | ### <br><br>[LICENSE](/mendableai/firecrawl/blob/main/LICENSE "LICENSE") |     |     |\n| ### <br><br>[README.md](/mendableai/firecrawl/blob/main/README.md "README.md") |     | ### <br><br>[README.md](/mendableai/firecrawl/blob/main/README.md "README.md") |     |     |\n| ### <br><br>[SELF\\_HOST.md](/mendableai/firecrawl/blob/main/SELF_HOST.md "SELF_HOST.md") |     | ### <br><br>[SELF\\_HOST.md](/mendableai/firecrawl/blob/main/SELF_HOST.md "SELF_HOST.md") |     |     |\n| ### <br><br>[docker-compose.yaml](/mendableai/firecrawl/blob/main/docker-compose.yaml "docker-compose.yaml") |     | ### <br><br>[docker-compose.yaml](/mendableai/firecrawl/blob/main/docker-compose.yaml "docker-compose.yaml") |     |     |\n| View all files |     |     |\n\nRepository files navigation\n---------------------------\n\n🔥 Firecrawl\n============\n\n[](#-firecrawl)\n\nCrawl and convert any website into LLM-ready markdown. Built by [Mendable.ai](https://mendable.ai?ref ...
#  Document(page_content=' [![Horizon Wiki](https://static.wikia.nocookie.net/horizonzerodawn/images/e/e6/Site-logo.png/revision/latest?cb=20210602034921)](//horizon.fandom.com)\n[Horizon Wiki](//horizon.fandom.com)\n\n[](/wiki/Special:Search "Search")\n[](/f "Discuss")\n[](# "Dark Theme")\n\nDon\'t have an account?\n\n[Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n\n* * *\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n\nAdvertisement\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n [Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n\nContents\n--------\n\n*   [1 History](#History)\n    \n*   [2 Appearance](#Appearance)\n    \n*   [3 Behavior](#Behavior)\n    \n*   [4 Abilities](#Abilities)\n    *   [4.1 Stances](#Stances)\n        \n    *   [4.2 Rock Shield](#Rock_Shield)\n        \n    *   [4.3 Fire Storm](#Fire_Storm)\n        \n    *   [4.4 Weaknesses](#Weaknesses)\n        \n    *   [4.5 Attacks](#Attacks)\n        *   [4.5.1 Horizon Zero Dawn](#Horizon_Zero_Dawn)\n            *   [4.5.1.1 Quadruped Stance](#Quadruped_Stance)\n                \n            *   [4.5.1.2 Biped Stance](#Biped_Stance)\n                \n            *   [4.5.1.3 Both Stances](#Both_Stances)\n                \n        *   [4.5.2 Horizon Forbidden West](#Horizon_Forbidden_West)\n            \n*   [5 Components](#Components)\n    *   [5.1 Horizon Zero Dawn](#Horizon_Zero_Dawn_2)\n        \n    *   [5.2 Horizon Forbidden West](#Horizon_Forbidden_West_2)\n        \n*   [6 Loot](#Loot)\n    *   [6.1 Horizon Zero Dawn](#Horizon_Zero_Dawn_3)\n        \n    *   [6.2 Horizon Forbidden West](#Horizon_Forbidden_West_3)\n        \n*   [7 Variants](#Variants)\n    \n*   [8 Trivia](#Trivia)\n    \n*   [9 Bugs](#Bugs)\n    \n*   [10 Gallery](#Gallery)\n    \n*   [11 Videos](#Videos)\n    \n*   [12 References](#References)\n    \n\n[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw%3Fveaction%3Dedit&uselang=en)\n\nin: [Machines](/wiki/Category:Machines "Category:Machines")\n, [Large Sized Machines](/wiki/Category:Large_Sized_Machines "Category:Large Sized Machines")\n, [EPSILON Override](/wiki/Category:EPSILON_Override "Category:EPSILON Override")\n,\n\nand 3 more\n\n*   [Acquisition Class](/wiki/Category:Acquisition_Class "Category:Acquisition Class")\n    \n*   [Frozen Wilds Machines](/wiki/Category:Frozen_Wilds_Machines "Category:Frozen Wilds Machines")\n    \n*   [CHI Override](/wiki/Category:CHI_Override "Category:CHI Override")\n    \n\nEnglish\n\n*   [Português do Brasil](https://horizon.fandom.com/pt-br/wiki/Garraquente)\n    \n*   [Русский](https://horizon.fandom.com/ru/wiki/%D0%9E%D0%B3%D0%BD%D0%B5%D0%BA%D0%BB%D1%8B%D0%BA)\n    \n\nFireclaw\n========\n\n[Sign in to edit](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw%3Fveaction%3Dedit&uselang=en)\n\n*   [View history](/wiki/Fireclaw?action=history)\n    \n*   [Talk (6)](/wiki/Talk:Fireclaw)\n    \n\n|     |     |\n| --- | --- |\n| ![RostHeadTransparent](...%3D%3D) | _**"The lesson will be taught in due time, Aloy. Until then, we wait."**_<br><br>This article contains heavy spoilers. Read ahead with caution. |\n\nThe **Fireclaw** is a heavyweight [machine](/wiki/Machine "Machine")\n introduced in [_The Frozen Wilds_](/wiki/Horizon_Zero_Dawn:_The_Frozen_Wilds "Horizon Zero Dawn: The Frozen Wilds")\n, with one serving as the final boss encounter of the DLC\'s story missions. They are a returning machine in _[Horizon Forbidden West](/wiki/Horizon_Forbidden_West "Horizon Forbidden West")\n_ and _[Horizon Call of the Mountain](/wiki/Horizon_Call_of_the_Mountain "Horizon Call of the Mountain")\n_. Like its twin machine the [Frostclaw](/wiki/Frostclaw "Frostc ...
#  Document(page_content=' \n\nClose search\n\nJust added to your cart\n-----------------------\n\nQty:\n\n[View cart ()](/cart)\n\nContinue shopping\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_300x300.jpg?v=1658703032)\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinesseClose......_300x300.jpg?v=1658703013)\n\n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_110x110@2x.jpg?v=1658703032)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_1024x1024@2x.jpg?v=1658703032)\n    \n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinesseClose......_110x110@2x.jpg?v=1658703013)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinesseClose......_1024x1024@2x.jpg?v=1658703013)\n    \n\nFire Craw\n=========\n\nWrite a review\n\nRegular price\n\n$5.29\n\nSale price\n\n$5.29 Sale\n\nUnit price\n\n/per\xa0\n\nAdding product to your cart\n\nFinesse worms can be rigged in a variety of ways, including wacky style on a small hook, on a darter head, splitshot or on a shakey or finesse jig head.\xa0 Its subtle action and natural undulations attract bass anywhere they swim.\n\nUse left/right arrows to navigate the slideshow or swipe left/right if using a mobile device\n\n*   choosing a selection results in a full page refresh\n*   press the space key then arrow keys to make a selection\n\n*   Opens in a new window.\n*   Opens external website.\n*   Opens external website in a new window.', metadata={'title': "Fire Craw\n– Moorer's Bait CompanyAmazonAmerican ExpressApple PayDiscoverMeta PayGoogle PayMastercardPayPalShop PayVenmoVisa", 'description': 'Finesse worms can be rigged in a variety of ways, including wacky style on a small hook, on a darter head, splitshot or on a shakey or finesse jig head.\xa0 Its subtle action and natural undulations attract bass anywhere they swim.', 'ogTitle': 'Fire Craw', 'ogDescription': 'Finesse worms can be rigged in a variety of ways, including wacky style on a small hook, on a darter head, splitshot or on a shakey or finesse jig head.\xa0 Its subtle action and natural undulations attract bass anywhere they swim.', 'ogUrl': 'https://www.moorersbaitcompany.com/products/fire-craw-1', 'ogImage': 'http://www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_1200x1200.jpg?v=1658703032', 'ogLocaleAlternate': [], 'ogSiteName': "Moorer's Bait Company", 'sourceURL': 'https://www.moorersbaitcompany.com/products/fire-craw-1'}),
#  Document(page_content='Jackhammer FIRE CRAW Trailer\n\nSearch\n\nWatch later\n\nShare\n\nCopy link\n\nInfo\n\nShopping\n\nTap to unmute\n\n2x\n\nIf playback doesn\'t begin shortly, try restarting your device.\n\n•\n\nUp next\n\nLive\n\nUpcoming\n\nCancelPlay Now\n\nYou\'re signed out\n\nVideos you watch may be added to the TV\'s watch history and influence TV recommendations. To avoid this, cancel and sign in to YouTube on your computer.\n\nCancelConfirm\n\n[Arcasting](https://www.youtube.com/channel/UCClVGWpCwxy8a6iXYMgpZQA)\n\nSubscribe\n\nSubscribed\n\nBass Fishing Michigan and the Great Lakes Region from the bank, boat, river and pond. Join me for amazing Largemouth Bass and Smallmouth Bass Fishing! Michigan has some of the best Fishing lakes in the world especially if your target is Largemouth Bass and Smallmouth Bass. Bass Fishing Videos, Fishing tackle videos, Fishing tips and techniques, Shimano reels, Monsterbass unboxings, vlogs and Fishing collaborations are what you can expect to see from my Michigan YouTube Channel. Subscribe for over 500 videos! 🎣\n\n[Summer Fishing Highly Pressured Kent Lake\\\n\\\n12:32](https://www.youtube.com/watch?v=_6jWf1wndxU)\n\n[Midland River Fishing BIG Smallmouth Bass\\\n\\\n11:31](https://www.youtube.com/watch?v=CnNF1EIuaQc)\n\n[Multi-Species Jerkbait Fishing Lake St. Clair\\\n\\\n14:01](https://www.youtube.com/watch?v=SQEXeVbV6Hs)\n\nShare\n\nInclude playlist\n\nAn error occurred while retrieving sharing information. Please try again later.\n\n0:00\n\n0:00 / 3:30•Live\n\n•\n\n•\n\nScroll for details\n\n•\n\n•\n\nBack [](/ "YouTube Home")\n\nSkip navigation\n\nSearch\n\nSearch with your voice\n\n[Sign in](https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252Fwatch%253Fv%253D7ag-j63tgNw&hl=en&ec=65620)\n\nJackhammer FIRE CRAW Trailer\n============================\n\n[](/@Arcasting1)\n\n[Arcasting](/@Arcasting1)\n\nArcasting\n\n36.1K subscribers\n\n<\\_\\_slot-el>\n\nSubscribe\n\n<\\_\\_slot-el>\n\nSubscribed\n\n178\n\nShare\n\nDownload\n\nDownload\n\nSave\n\n6.2K views 3 years ago [#jackhammer](/hashtag/jackhammer)\n [#chatterbait](/hashtag/chatterbait)\n [#firecraw](/hashtag/firecraw)\n\n6,210 views • Feb 6, 2021 • #jackhammer #chatterbait #firecraw\n\n[Relaxer\\\n=======\\\n\\\n#### The Grand Affair\\\n\\\nRelaxer](/watch?v=b0qxuU4Wq9o)\n\n[Music](/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ)\n\nFollow along using the transcript.\n\nShow transcript\n\n[Videos](/channel/UCClVGWpCwxy8a6iXYMgpZQA/videos)\n\n[About](/channel/UCClVGWpCwxy8a6iXYMgpZQA/about)\n\n[Videos](/channel/UCClVGWpCwxy8a6iXYMgpZQA/videos)\n[About](/channel/UCClVGWpCwxy8a6iXYMgpZQA/about)\n[Subscribe](https://www.youtube.com/channel/UCClVGWpCwxy8a6iXYMgpZQA/featured)\n\nShow less\n\nJackhammer Fire Craw Trailer video. My favorite trailer for the jackhammer fire craw chatterbait is a strike king rage craw in the delta red color. This red colored rage craw goes very good with the jackhammer fire craw and I would even call it the best color rage craw for this chatterbait. Delta Red and Falcon Lake Craw have to be my favorite craw colored trailers for the Jackhammer Fire Craw Chatterbait. Subscribe Here ------------------------------------------------------------------------------------------------------------ \xa0\xa0\xa0[![](https://www.gstatic.com/youtube/img/watch/yt_favicon.png)\xa0/\xa0@arcasting1](/channel/UCClVGWpCwxy8a6iXYMgpZQA)\xa0\xa0 MICHIGAN BASS FISHING VIDEOS ------------------------------------------------------------------------------------------------------------ PB Bass - \xa0\xa0\xa0[![](https://www.gstatic.com/youtube/img/watch/yt_favicon.png)\xa0•\xa0NEW\xa0Personal\xa0BEST\xa0Michigan\xa0BASS!](/watch?v=DyFktt9n0Sg&t=0s)\xa0\xa0 Tube Fishing - \xa0\xa0\xa0[![](https://www.gstatic.com/youtube/img/watch/yt_favicon.png)\xa0•\xa0Summer\xa ...
#  Document(page_content=' [![Arwingpedia](https://static.wikia.nocookie.net/starfox/images/e/e6/Site-logo.png/revision/latest?cb=20210616185110)](//starfox.fandom.com)\n[Arwingpedia](//starfox.fandom.com)\n\n[](/wiki/Special:Search "Search")\n[](/f "Discuss")\n[](# "Dark Theme")\n\nDon\'t have an account?\n\n[Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n\n* * *\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n\nAdvertisement\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n [Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n\nContents\n--------\n\n*   [1 Description](#Description)\n    *   [1.1 P.D.A Scanner Information](#P.D.A_Scanner_Information)\n        \n    *   [1.2 FireCrawlers](#FireCrawlers)\n        *   [1.2.1 Description:](#Description:)\n            \n        *   [1.2.2 Attacks:](#Attacks:)\n            \n        *   [1.2.3 Tactics:](#Tactics:)\n            \n    *   [1.3 Society and Culture](#Society_and_Culture)\n        \n*   [2 Gallery](#Gallery)\n    \n*   [3 Trivia](#Trivia)\n    \n*   [4 References](#References)\n    \n\n[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit&uselang=en)\n\nin: [Dinosaur tribes](/wiki/Category:Dinosaur_tribes "Category:Dinosaur tribes")\n, [Lifeforms](/wiki/Category:Lifeforms "Category:Lifeforms")\n, [Unknown status](/wiki/Category:Unknown_status "Category:Unknown status")\n, [Star Fox Adventures Enemies](/wiki/Category:Star_Fox_Adventures_Enemies "Category:Star Fox Adventures Enemies")\n\nFireCrawler\n===========\n\n[Sign in to edit](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit&uselang=en)\n\n*   [View history](/wiki/FireCrawler?action=history)\n    \n*   [Talk (0)](/wiki/Talk:FireCrawler?action=edit&redlink=1)\n    \n\n  \n**FireCrawlers** are a group of hostile, fire-breathing enemies native to Dinosaur Planet.\n\nContents\n--------\n\n*   [1 Description](#Description)\n    *   [1.1 P.D.A Scanner Information](#P.D.A_Scanner_Information)\n        \n    *   [1.2 FireCrawlers](#FireCrawlers)\n        *   [1.2.1 Description:](#Description:)\n            \n        *   [1.2.2 Attacks:](#Attacks:)\n            \n        *   [1.2.3 Tactics:](#Tactics:)\n            \n    *   [1.3 Society and Culture](#Society_and_Culture)\n        \n*   [2 Gallery](#Gallery)\n    \n*   [3 Trivia](#Trivia)\n    \n*   [4 References](#References)\n    \n\n**Description**\\[[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit%26section%3D1&uselang=en "Sign in to edit")\\\n\\]\n----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------\n\nThey resemble the real world\xa0Ankylosaurid family, as they are armoured, yet they lack the defensive club tail of that family.\xa0They have two limbs, which are forelegs. When attacked, they retract into their shells as modern-day turtles do, while shrouding themselves in fire, but as a result, they are vulnerable to Fox\'s attacks. As their name implies, they can breath fireballs at their prey from a distance. Fox can take damage just by touching them.\xa0The quickest way to defeat one is to use the [Ice Blaster](/wiki/Ice_Blaster "Ice Blaster")\n\xa0technique, and then hit them.\n\n### [P.D.A Scanner Information](/wiki/P.D.A "P.D.A")\n\\[[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit%26section%3D2&uselang=en "Sign in to edit")\\\n\\]\n\n_**FIRECRAWLER -**\xa0Use your Ice Blast!_\n\n### _**FireCrawlers**_\\[[](https://au ...
#  Document(page_content=' \n\nClose search\n\nJust added to your cart\n-----------------------\n\nQty:\n\n[View cart ()](/cart)\n\nContinue shopping\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_300x300.jpg?v=1661392828)\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbaitClose........_300x300.jpg?v=1661392822)\n\n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_110x110@2x.jpg?v=1661392828)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_1024x1024@2x.jpg?v=1661392828)\n    \n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbaitClose........_110x110@2x.jpg?v=1661392822)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbaitClose........_1024x1024@2x.jpg?v=1661392822)\n    \n\nFire Craw\n=========\n\nWrite a review\n\nRegular price\n\n$5.99\n\nSale price\n\n$5.99 Sale\n\nUnit price\n\n/per\xa0\n\nAdding product to your cart\n\nSwimbaits are a go to for many anglers. It is an extremely versatile bait that can be fished many different ways; Texas Rig, Spinnerbait, Jig Trailer, Umbrella Rig, and even a Carolina Rig. The ribbed body creates alot of water movement to make even the most finicky fish bite it.\n\nUse left/right arrows to navigate the slideshow or swipe left/right if using a mobile device\n\n*   choosing a selection results in a full page refresh\n*   press the space key then arrow keys to make a selection\n\n*   Opens in a new window.\n*   Opens external website.\n*   Opens external website in a new window.', metadata={'title': "Fire Craw\n– Moorer's Bait CompanyAmazonAmerican ExpressApple PayDiscoverMeta PayGoogle PayMastercardPayPalShop PayVenmoVisa", 'description': 'Swimbaits are a go to for many anglers. It is an extremely versatile bait that can be fished many different ways; Texas Rig, Spinnerbait, Jig Trailer, Umbrella Rig, and even a Carolina Rig. The ribbed body creates alot of water movement to make even the most finicky fish bite it.', 'ogTitle': 'Fire Craw', 'ogDescription': 'Swimbaits are a go to for many anglers. It is an extremely versatile bait that can be fished many different ways; Texas Rig, Spinnerbait, Jig Trailer, Umbrella Rig, and even a Carolina Rig. The ribbed body creates alot of water movement to make even the most finicky fish bite it.', 'ogUrl': 'https://www.moorersbaitcompany.com/products/fire-craw', 'ogImage': 'http://www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_1200x1200.jpg?v=1661392828', 'ogLocaleAlternate': [], 'ogSiteName': "Moorer's Bait Company", 'sourceURL': 'https://www.moorersbaitcompany.com/products/fire-craw'})]

# %% [markdown]
# ## Modes
#
# - `scrape`: Scrape single url and return the markdown.
# - `crawl`: Crawl the url and all accessible sub pages and return the markdown for each one.
# - `search`: Search the web for a query and return the markdown for the found pages.

# %% [markdown]
# ### Crawl

# %%
loader = FireCrawlLoader(
    api_key="YOUR_API_KEY",
    url="https://firecrawl.dev",
    mode="scrape",
)

# %%
data = loader.load()

# %%
data
# Out:
# [Document(page_content='[Skip to content](#skip)\n\n[🔥 FireCrawl](/)\n\n[Playground](/playground)\n[Pricing](/pricing)\n\n[Log In](/signin)\n[Log In](/signin)\n[Sign Up](/signin/signup)\n\n![Slack Logo](/images/slack_logo_icon.png)\n\nNew message in: #coach-gtm\n==========================\n\n@CoachGTM: Your meeting prep for Pied Piper < > WindFlow Dynamics is ready! Meeting starts in 30 minutes\n\nTurn websites into  \n_LLM-ready_ data\n=====================================\n\nCrawl and convert any website into clean markdown\n\nTry now (100 free credits)No credit card required\n\nA product by\n\n[![Mendable Logo](/images/mendable_logo_transparent.png)Mendable](https://mendable.ai)\n\n![Mendable Website Image](/mendable-hero-8.png)\n\nCrawl, Capture, Clean\n---------------------\n\nWe crawl all accessible subpages and give you clean markdown for each. No sitemap required.\n\n    \n      [\\\n        {\\\n          "url": "https://www.mendable.ai/",\\\n          "markdown": "## Welcome to Mendable\\\n            Mendable empowers teams with AI-driven solutions - \\\n            streamlining sales and support."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/features",\\\n          "markdown": "## Features\\\n            Discover how Mendable\'s cutting-edge features can \\\n            transform your business operations."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/pricing",\\\n          "markdown": "## Pricing Plans\\\n            Choose the perfect plan that fits your business needs."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/about",\\\n          "markdown": "## About Us\\\n          \\\n            Learn more about Mendable\'s mission and the \\\n            team behind our innovative platform."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/contact",\\\n          "markdown": "## Contact Us\\\n            Get in touch with us for any queries or support."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/blog",\\\n          "markdown": "## Blog\\\n            Stay updated with the latest news and insights from Mendable."\\\n        }\\\n      ]\n      \n\nNote: The markdown has been edited for display purposes.\n\nWe handle the hard stuff\n------------------------\n\nReverse proxyies, caching, rate limits, js-blocked content and more...\n\n#### Crawling\n\nFireCrawl crawls all accessible subpages, even without a sitemap.\n\n#### Dynamic content\n\nFireCrawl gathers data even if a website uses javascript to render content.\n\n#### To Markdown\n\nFireCrawl returns clean, well formatted markdown - ready for use in LLM applications\n\n#### Continuous updates\n\nSchedule syncs with FireCrawl. No cron jobs or orchestration required.\n\n#### Caching\n\nFireCrawl caches content, so you don\'t have to wait for a full scrape unless new content exists.\n\n#### Built for AI\n\nBuilt by LLM engineers, for LLM engineers. Giving you clean data the way you want it.\n\nPricing Plans\n=============\n\nStarter\n-------\n\n50k credits ($1.00/1k)\n\n$50/month\n\n*   Scrape 50,000 pages\n*   Credits valid for 6 months\n*   2 simultaneous scrapers\\*\n\nSubscribe\n\nStandard\n--------\n\n500k credits ($0.75/1k)\n\n$375/month\n\n*   Scrape 500,000 pages\n*   Credits valid for 6 months\n*   4 simultaneous scrapers\\*\n\nSubscribe\n\nScale\n-----\n\n12.5M credits ($0.30/1k)\n\n$1,250/month\n\n*   Scrape 2,500,000 pages\n*   Credits valid for 6 months\n*   10 simultaneous scrapes\\*\n\nSubscribe\n\n\\* a "scraper" refers to how many scraper jobs you can simultaneously submit.\n\nWhat sites work?\n----------------\n\nFirecrawl is best suited for business websites, docs and help centers.\n\nBuisness websites\n\nGathering business intelligence or connecting company data to your AI\n\nBlogs, Documentation and Help centers\n\nGather content from documentation and other textual sources\n\nSocial Media\n\nComing soon\n\n![Feature 01 ...

# %% [markdown]
# #### Crawl Options
#
# You can also pass `params` to the loader. This is a dictionary of options to pass to the crawler. See the [FireCrawl API documentation](https://github.com/mendableai/firecrawl-py) for more information.

# %% [markdown]
# ### Search

# %%
loader = FireCrawlLoader(
    api_key="YOUR_API_KEY", query="what is firecrawl?", mode="search"
)

# %%
docs = loader.load()

# %%
docs
# Out:
# [Document(page_content='Introducing [LLM Extraction!](https://firecrawl.dev/playground?mode=llm-extract)\n Convert any web page into structured data using LLMs\n\n![Slack Logo](/images/slack_logo_icon.png)\n\nNew message in: #coach-gtm\n==========================\n\n@CoachGTM: Your meeting prep for Pied Piper < > WindFlow Dynamics is ready! Meeting starts in 30 minutes\n\n[🦜🔗 Check out our LangChain integration](https://python.langchain.com/docs/integrations/document_loaders/firecrawl/)\n\nTurn websites into  \n_LLM-ready_ data\n=====================================\n\nCrawl and convert any website into clean markdown or structured data\n\nTry now 300 free creditsNo credit card required\n\nA product by\n\n[![Mendable Logo](/images/mendable_logo_transparent.png)Mendable](https://mendable.ai)\n\n![Mendable Website Image](/mendable-hero-8.webp)\n\nCrawl, Capture, Clean\n---------------------\n\nWe crawl all accessible subpages and give you clean markdown for each. No sitemap required.\n\n    \n      [\\\n        {\\\n          "url": "https://www.mendable.ai/",\\\n          "markdown": "## Welcome to Mendable\\\n            Mendable empowers teams with AI-driven solutions - \\\n            streamlining sales and support."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/features",\\\n          "markdown": "## Features\\\n            Discover how Mendable\'s cutting-edge features can \\\n            transform your business operations."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/pricing",\\\n          "markdown": "## Pricing Plans\\\n            Choose the perfect plan that fits your business needs."\\\n        },\\\n        {\\\n          "url": "https://www.mendable.ai/about",\\\n          "markdown": "## About Us\\\n            Learn more about Mendable\'s mission and the \\\n            team behind our innovative platform."\\\n        }\\\n      ]\n      \n\nNote: The markdown has been edited for display purposes.\n\nWe handle the hard stuff\n------------------------\n\nProxies, caching, rate limits, js-blocked content and more...\n\n#### Crawling\n\nFireCrawl crawls all accessible subpages, even without a sitemap.\n\n#### Dynamic content\n\nFireCrawl gathers data even if a website uses javascript to render content.\n\n#### To Markdown\n\nFireCrawl returns clean, well formatted markdown - ready for use in LLM applications\n\n#### Crawling Orchestration\n\nFireCrawl orchestrates the crawling process in parallel for the fastest results.\n\n#### Caching\n\nFireCrawl caches content, so you don\'t have to wait for a full scrape unless new content exists.\n\n#### Built for AI\n\nBuilt by LLM engineers, for LLM engineers. Giving you clean data the way you want it.\n\nOur wall of love\n\nDon\'t take our word for it\n--------------------------\n\n![Greg Kamradt](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-02.0afeb750.jpg&w=96&q=75)\n\nGreg Kamradt\n\n[@GregKamradt](https://twitter.com/GregKamradt/status/1780300642197840307)\n\nLLM structured data via API, handling requests, cleaning, and crawling. Enjoyed the early preview.\n\n![Amit Naik](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-03.ff5dbe11.jpg&w=96&q=75)\n\nAmit Naik\n\n[@suprgeek](https://twitter.com/suprgeek/status/1780338213351035254)\n\n#llm success with RAG relies on Retrieval. Firecrawl by @mendableai structures web content for processing. 👏\n\n![Jerry Liu](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-04.76bef0df.jpg&w=96&q=75)\n\nJerry Liu\n\n[@jerryjliu0](https://twitter.com/jerryjliu0/status/1781122933349572772)\n\nFirecrawl is awesome 🔥 Turns web pages into structured markdown for LLM apps, thanks to @mendableai.\n\n![Bardia Pourvakil](/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Ftestimonial-01.025350bc.jpeg&w=96&q=75)\n\nBardia Pourvakil\n\n[@thepericulum](https://twitter.com/thepericulum/status/1781397799487078874)\n\nThese guys ship. I wanted types for their node SDK, and less tha ...
#  Document(page_content='\n\nYou signed in with another tab or window. Reload to refresh your session. You signed out in another tab or window. Reload to refresh your session. You switched accounts on another tab or window. Reload to refresh your session. Dismiss alert\n\n/ **[firecrawl](/mendableai/firecrawl)** Public\n\n*   [Notifications](/login?return_to=%2Fmendableai%2Ffirecrawl)\n    \n*   [Fork 242](/login?return_to=%2Fmendableai%2Ffirecrawl)\n    \n*   [Star 2.9k](/login?return_to=%2Fmendableai%2Ffirecrawl)\n    \n\n🔥 Turn entire websites into LLM-ready markdown\n\n[firecrawl.dev](https://firecrawl.dev "https://firecrawl.dev")\n\n### License\n\n[AGPL-3.0 license](/mendableai/firecrawl/blob/main/LICENSE)\n\n[2.9k stars](/mendableai/firecrawl/stargazers)\n [242 forks](/mendableai/firecrawl/forks)\n [Branches](/mendableai/firecrawl/branches)\n [Tags](/mendableai/firecrawl/tags)\n [Activity](/mendableai/firecrawl/activity)\n\n[Star](/login?return_to=%2Fmendableai%2Ffirecrawl)\n\n[Notifications](/login?return_to=%2Fmendableai%2Ffirecrawl)\n\nmendableai/firecrawl\n====================\n\nThis commit does not belong to any branch on this repository, and may belong to a fork outside of the repository.\n\n\xa0main\n\n[Branches](/mendableai/firecrawl/branches)\n[Tags](/mendableai/firecrawl/tags)\n\n[](/mendableai/firecrawl/branches)\n[](/mendableai/firecrawl/tags)\n\nGo to file\n\nCode\n\nFolders and files\n-----------------\n\n| Name |     | Name | Last commit message | Last commit date |\n| --- | --- | --- | --- |\n| Latest commit<br>-------------<br><br>History<br>-------<br><br>[394 Commits](/mendableai/firecrawl/commits/main/)<br><br>[](/mendableai/firecrawl/commits/main/) |     |     |\n| ### <br><br>[.github/workflows](/mendableai/firecrawl/tree/main/.github/workflows "This path skips through empty directories") |     | ### <br><br>[.github/workflows](/mendableai/firecrawl/tree/main/.github/workflows "This path skips through empty directories") |     |     |\n| ### <br><br>[apps](/mendableai/firecrawl/tree/main/apps "apps") |     | ### <br><br>[apps](/mendableai/firecrawl/tree/main/apps "apps") |     |     |\n| ### <br><br>[tutorials](/mendableai/firecrawl/tree/main/tutorials "tutorials") |     | ### <br><br>[tutorials](/mendableai/firecrawl/tree/main/tutorials "tutorials") |     |     |\n| ### <br><br>[.gitattributes](/mendableai/firecrawl/blob/main/.gitattributes ".gitattributes") |     | ### <br><br>[.gitattributes](/mendableai/firecrawl/blob/main/.gitattributes ".gitattributes") |     |     |\n| ### <br><br>[.gitignore](/mendableai/firecrawl/blob/main/.gitignore ".gitignore") |     | ### <br><br>[.gitignore](/mendableai/firecrawl/blob/main/.gitignore ".gitignore") |     |     |\n| ### <br><br>[CONTRIBUTING.md](/mendableai/firecrawl/blob/main/CONTRIBUTING.md "CONTRIBUTING.md") |     | ### <br><br>[CONTRIBUTING.md](/mendableai/firecrawl/blob/main/CONTRIBUTING.md "CONTRIBUTING.md") |     |     |\n| ### <br><br>[LICENSE](/mendableai/firecrawl/blob/main/LICENSE "LICENSE") |     | ### <br><br>[LICENSE](/mendableai/firecrawl/blob/main/LICENSE "LICENSE") |     |     |\n| ### <br><br>[README.md](/mendableai/firecrawl/blob/main/README.md "README.md") |     | ### <br><br>[README.md](/mendableai/firecrawl/blob/main/README.md "README.md") |     |     |\n| ### <br><br>[SELF\\_HOST.md](/mendableai/firecrawl/blob/main/SELF_HOST.md "SELF_HOST.md") |     | ### <br><br>[SELF\\_HOST.md](/mendableai/firecrawl/blob/main/SELF_HOST.md "SELF_HOST.md") |     |     |\n| ### <br><br>[docker-compose.yaml](/mendableai/firecrawl/blob/main/docker-compose.yaml "docker-compose.yaml") |     | ### <br><br>[docker-compose.yaml](/mendableai/firecrawl/blob/main/docker-compose.yaml "docker-compose.yaml") |     |     |\n| View all files |     |     |\n\nRepository files navigation\n---------------------------\n\n🔥 Firecrawl\n============\n\n[](#-firecrawl)\n\nCrawl and convert any website into LLM-ready markdown. Built by [Mendable.ai](https://mendable.ai?ref ...
#  Document(page_content=' [![Horizon Wiki](https://static.wikia.nocookie.net/horizonzerodawn/images/e/e6/Site-logo.png/revision/latest?cb=20210602034921)](//horizon.fandom.com)\n[Horizon Wiki](//horizon.fandom.com)\n\n[](/wiki/Special:Search "Search")\n[](/f "Discuss")\n[](# "Dark Theme")\n\nDon\'t have an account?\n\n[Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n\n* * *\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n\nAdvertisement\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n [Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw)\n\nContents\n--------\n\n*   [1 History](#History)\n    \n*   [2 Appearance](#Appearance)\n    \n*   [3 Behavior](#Behavior)\n    \n*   [4 Abilities](#Abilities)\n    *   [4.1 Stances](#Stances)\n        \n    *   [4.2 Rock Shield](#Rock_Shield)\n        \n    *   [4.3 Fire Storm](#Fire_Storm)\n        \n    *   [4.4 Weaknesses](#Weaknesses)\n        \n    *   [4.5 Attacks](#Attacks)\n        *   [4.5.1 Horizon Zero Dawn](#Horizon_Zero_Dawn)\n            *   [4.5.1.1 Quadruped Stance](#Quadruped_Stance)\n                \n            *   [4.5.1.2 Biped Stance](#Biped_Stance)\n                \n            *   [4.5.1.3 Both Stances](#Both_Stances)\n                \n        *   [4.5.2 Horizon Forbidden West](#Horizon_Forbidden_West)\n            \n*   [5 Components](#Components)\n    *   [5.1 Horizon Zero Dawn](#Horizon_Zero_Dawn_2)\n        \n    *   [5.2 Horizon Forbidden West](#Horizon_Forbidden_West_2)\n        \n*   [6 Loot](#Loot)\n    *   [6.1 Horizon Zero Dawn](#Horizon_Zero_Dawn_3)\n        \n    *   [6.2 Horizon Forbidden West](#Horizon_Forbidden_West_3)\n        \n*   [7 Variants](#Variants)\n    \n*   [8 Trivia](#Trivia)\n    \n*   [9 Bugs](#Bugs)\n    \n*   [10 Gallery](#Gallery)\n    \n*   [11 Videos](#Videos)\n    \n*   [12 References](#References)\n    \n\n[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw%3Fveaction%3Dedit&uselang=en)\n\nin: [Machines](/wiki/Category:Machines "Category:Machines")\n, [Large Sized Machines](/wiki/Category:Large_Sized_Machines "Category:Large Sized Machines")\n, [EPSILON Override](/wiki/Category:EPSILON_Override "Category:EPSILON Override")\n,\n\nand 3 more\n\n*   [Acquisition Class](/wiki/Category:Acquisition_Class "Category:Acquisition Class")\n    \n*   [Frozen Wilds Machines](/wiki/Category:Frozen_Wilds_Machines "Category:Frozen Wilds Machines")\n    \n*   [CHI Override](/wiki/Category:CHI_Override "Category:CHI Override")\n    \n\nEnglish\n\n*   [Português do Brasil](https://horizon.fandom.com/pt-br/wiki/Garraquente)\n    \n*   [Русский](https://horizon.fandom.com/ru/wiki/%D0%9E%D0%B3%D0%BD%D0%B5%D0%BA%D0%BB%D1%8B%D0%BA)\n    \n\nFireclaw\n========\n\n[Sign in to edit](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fhorizon.fandom.com%2Fwiki%2FFireclaw%3Fveaction%3Dedit&uselang=en)\n\n*   [View history](/wiki/Fireclaw?action=history)\n    \n*   [Talk (6)](/wiki/Talk:Fireclaw)\n    \n\n|     |     |\n| --- | --- |\n| ![RostHeadTransparent](...%3D%3D) | _**"The lesson will be taught in due time, Aloy. Until then, we wait."**_<br><br>This article contains heavy spoilers. Read ahead with caution. |\n\nThe **Fireclaw** is a heavyweight [machine](/wiki/Machine "Machine")\n introduced in [_The Frozen Wilds_](/wiki/Horizon_Zero_Dawn:_The_Frozen_Wilds "Horizon Zero Dawn: The Frozen Wilds")\n, with one serving as the final boss encounter of the DLC\'s story missions. They are a returning machine in _[Horizon Forbidden West](/wiki/Horizon_Forbidden_West "Horizon Forbidden West")\n_ and _[Horizon Call of the Mountain](/wiki/Horizon_Call_of_the_Mountain "Horizon Call of the Mountain")\n_. Like its twin machine the [Frostclaw](/wiki/Frostclaw "Frostc ...
#  Document(page_content=' \n\nClose search\n\nJust added to your cart\n-----------------------\n\nQty:\n\n[View cart ()](/cart)\n\nContinue shopping\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_300x300.jpg?v=1658703032)\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinesseClose......_300x300.jpg?v=1658703013)\n\n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_110x110@2x.jpg?v=1658703032)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_1024x1024@2x.jpg?v=1658703032)\n    \n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinesseClose......_110x110@2x.jpg?v=1658703013)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinesseClose......_1024x1024@2x.jpg?v=1658703013)\n    \n\nFire Craw\n=========\n\nWrite a review\n\nRegular price\n\n$5.29\n\nSale price\n\n$5.29 Sale\n\nUnit price\n\n/per\xa0\n\nAdding product to your cart\n\nFinesse worms can be rigged in a variety of ways, including wacky style on a small hook, on a darter head, splitshot or on a shakey or finesse jig head.\xa0 Its subtle action and natural undulations attract bass anywhere they swim.\n\nUse left/right arrows to navigate the slideshow or swipe left/right if using a mobile device\n\n*   choosing a selection results in a full page refresh\n*   press the space key then arrow keys to make a selection\n\n*   Opens in a new window.\n*   Opens external website.\n*   Opens external website in a new window.', metadata={'title': "Fire Craw\n– Moorer's Bait CompanyAmazonAmerican ExpressApple PayDiscoverMeta PayGoogle PayMastercardPayPalShop PayVenmoVisa", 'description': 'Finesse worms can be rigged in a variety of ways, including wacky style on a small hook, on a darter head, splitshot or on a shakey or finesse jig head.\xa0 Its subtle action and natural undulations attract bass anywhere they swim.', 'ogTitle': 'Fire Craw', 'ogDescription': 'Finesse worms can be rigged in a variety of ways, including wacky style on a small hook, on a darter head, splitshot or on a shakey or finesse jig head.\xa0 Its subtle action and natural undulations attract bass anywhere they swim.', 'ogUrl': 'https://www.moorersbaitcompany.com/products/fire-craw-1', 'ogImage': 'http://www.moorersbaitcompany.com/cdn/shop/products/FireCrawFinessee_1200x1200.jpg?v=1658703032', 'ogLocaleAlternate': [], 'ogSiteName': "Moorer's Bait Company", 'sourceURL': 'https://www.moorersbaitcompany.com/products/fire-craw-1'}),
#  Document(page_content='Jackhammer FIRE CRAW Trailer\n\nSearch\n\nWatch later\n\nShare\n\nCopy link\n\nInfo\n\nShopping\n\nTap to unmute\n\n2x\n\nIf playback doesn\'t begin shortly, try restarting your device.\n\n•\n\nUp next\n\nLive\n\nUpcoming\n\nCancelPlay Now\n\nYou\'re signed out\n\nVideos you watch may be added to the TV\'s watch history and influence TV recommendations. To avoid this, cancel and sign in to YouTube on your computer.\n\nCancelConfirm\n\n[Arcasting](https://www.youtube.com/channel/UCClVGWpCwxy8a6iXYMgpZQA)\n\nSubscribe\n\nSubscribed\n\nBass Fishing Michigan and the Great Lakes Region from the bank, boat, river and pond. Join me for amazing Largemouth Bass and Smallmouth Bass Fishing! Michigan has some of the best Fishing lakes in the world especially if your target is Largemouth Bass and Smallmouth Bass. Bass Fishing Videos, Fishing tackle videos, Fishing tips and techniques, Shimano reels, Monsterbass unboxings, vlogs and Fishing collaborations are what you can expect to see from my Michigan YouTube Channel. Subscribe for over 500 videos! 🎣\n\n[Summer Fishing Highly Pressured Kent Lake\\\n\\\n12:32](https://www.youtube.com/watch?v=_6jWf1wndxU)\n\n[Midland River Fishing BIG Smallmouth Bass\\\n\\\n11:31](https://www.youtube.com/watch?v=CnNF1EIuaQc)\n\n[Multi-Species Jerkbait Fishing Lake St. Clair\\\n\\\n14:01](https://www.youtube.com/watch?v=SQEXeVbV6Hs)\n\nShare\n\nInclude playlist\n\nAn error occurred while retrieving sharing information. Please try again later.\n\n0:00\n\n0:00 / 3:30•Live\n\n•\n\n•\n\nScroll for details\n\n•\n\n•\n\nBack [](/ "YouTube Home")\n\nSkip navigation\n\nSearch\n\nSearch with your voice\n\n[Sign in](https://accounts.google.com/ServiceLogin?service=youtube&uilel=3&passive=true&continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Den%26next%3Dhttps%253A%252F%252Fwww.youtube.com%252Fwatch%253Fv%253D7ag-j63tgNw&hl=en&ec=65620)\n\nJackhammer FIRE CRAW Trailer\n============================\n\n[](/@Arcasting1)\n\n[Arcasting](/@Arcasting1)\n\nArcasting\n\n36.1K subscribers\n\n<\\_\\_slot-el>\n\nSubscribe\n\n<\\_\\_slot-el>\n\nSubscribed\n\n178\n\nShare\n\nDownload\n\nDownload\n\nSave\n\n6.2K views 3 years ago [#jackhammer](/hashtag/jackhammer)\n [#chatterbait](/hashtag/chatterbait)\n [#firecraw](/hashtag/firecraw)\n\n6,210 views • Feb 6, 2021 • #jackhammer #chatterbait #firecraw\n\n[Relaxer\\\n=======\\\n\\\n#### The Grand Affair\\\n\\\nRelaxer](/watch?v=b0qxuU4Wq9o)\n\n[Music](/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ)\n\nFollow along using the transcript.\n\nShow transcript\n\n[Videos](/channel/UCClVGWpCwxy8a6iXYMgpZQA/videos)\n\n[About](/channel/UCClVGWpCwxy8a6iXYMgpZQA/about)\n\n[Videos](/channel/UCClVGWpCwxy8a6iXYMgpZQA/videos)\n[About](/channel/UCClVGWpCwxy8a6iXYMgpZQA/about)\n[Subscribe](https://www.youtube.com/channel/UCClVGWpCwxy8a6iXYMgpZQA/featured)\n\nShow less\n\nJackhammer Fire Craw Trailer video. My favorite trailer for the jackhammer fire craw chatterbait is a strike king rage craw in the delta red color. This red colored rage craw goes very good with the jackhammer fire craw and I would even call it the best color rage craw for this chatterbait. Delta Red and Falcon Lake Craw have to be my favorite craw colored trailers for the Jackhammer Fire Craw Chatterbait. Subscribe Here ------------------------------------------------------------------------------------------------------------ \xa0\xa0\xa0[![](https://www.gstatic.com/youtube/img/watch/yt_favicon.png)\xa0/\xa0@arcasting1](/channel/UCClVGWpCwxy8a6iXYMgpZQA)\xa0\xa0 MICHIGAN BASS FISHING VIDEOS ------------------------------------------------------------------------------------------------------------ PB Bass - \xa0\xa0\xa0[![](https://www.gstatic.com/youtube/img/watch/yt_favicon.png)\xa0•\xa0NEW\xa0Personal\xa0BEST\xa0Michigan\xa0BASS!](/watch?v=DyFktt9n0Sg&t=0s)\xa0\xa0 Tube Fishing - \xa0\xa0\xa0[![](https://www.gstatic.com/youtube/img/watch/yt_favicon.png)\xa0•\xa0Summer\xa ...
#  Document(page_content=' [![Arwingpedia](https://static.wikia.nocookie.net/starfox/images/e/e6/Site-logo.png/revision/latest?cb=20210616185110)](//starfox.fandom.com)\n[Arwingpedia](//starfox.fandom.com)\n\n[](/wiki/Special:Search "Search")\n[](/f "Discuss")\n[](# "Dark Theme")\n\nDon\'t have an account?\n\n[Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n\n* * *\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n\nAdvertisement\n\n[Sign In](https://auth.fandom.com/signin?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n [Register](https://auth.fandom.com/register?source=mw&redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler)\n\nContents\n--------\n\n*   [1 Description](#Description)\n    *   [1.1 P.D.A Scanner Information](#P.D.A_Scanner_Information)\n        \n    *   [1.2 FireCrawlers](#FireCrawlers)\n        *   [1.2.1 Description:](#Description:)\n            \n        *   [1.2.2 Attacks:](#Attacks:)\n            \n        *   [1.2.3 Tactics:](#Tactics:)\n            \n    *   [1.3 Society and Culture](#Society_and_Culture)\n        \n*   [2 Gallery](#Gallery)\n    \n*   [3 Trivia](#Trivia)\n    \n*   [4 References](#References)\n    \n\n[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit&uselang=en)\n\nin: [Dinosaur tribes](/wiki/Category:Dinosaur_tribes "Category:Dinosaur tribes")\n, [Lifeforms](/wiki/Category:Lifeforms "Category:Lifeforms")\n, [Unknown status](/wiki/Category:Unknown_status "Category:Unknown status")\n, [Star Fox Adventures Enemies](/wiki/Category:Star_Fox_Adventures_Enemies "Category:Star Fox Adventures Enemies")\n\nFireCrawler\n===========\n\n[Sign in to edit](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit&uselang=en)\n\n*   [View history](/wiki/FireCrawler?action=history)\n    \n*   [Talk (0)](/wiki/Talk:FireCrawler?action=edit&redlink=1)\n    \n\n  \n**FireCrawlers** are a group of hostile, fire-breathing enemies native to Dinosaur Planet.\n\nContents\n--------\n\n*   [1 Description](#Description)\n    *   [1.1 P.D.A Scanner Information](#P.D.A_Scanner_Information)\n        \n    *   [1.2 FireCrawlers](#FireCrawlers)\n        *   [1.2.1 Description:](#Description:)\n            \n        *   [1.2.2 Attacks:](#Attacks:)\n            \n        *   [1.2.3 Tactics:](#Tactics:)\n            \n    *   [1.3 Society and Culture](#Society_and_Culture)\n        \n*   [2 Gallery](#Gallery)\n    \n*   [3 Trivia](#Trivia)\n    \n*   [4 References](#References)\n    \n\n**Description**\\[[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit%26section%3D1&uselang=en "Sign in to edit")\\\n\\]\n----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------\n\nThey resemble the real world\xa0Ankylosaurid family, as they are armoured, yet they lack the defensive club tail of that family.\xa0They have two limbs, which are forelegs. When attacked, they retract into their shells as modern-day turtles do, while shrouding themselves in fire, but as a result, they are vulnerable to Fox\'s attacks. As their name implies, they can breath fireballs at their prey from a distance. Fox can take damage just by touching them.\xa0The quickest way to defeat one is to use the [Ice Blaster](/wiki/Ice_Blaster "Ice Blaster")\n\xa0technique, and then hit them.\n\n### [P.D.A Scanner Information](/wiki/P.D.A "P.D.A")\n\\[[](https://auth.fandom.com/signin?redirect=https%3A%2F%2Fstarfox.fandom.com%2Fwiki%2FFireCrawler%3Fveaction%3Dedit%26section%3D2&uselang=en "Sign in to edit")\\\n\\]\n\n_**FIRECRAWLER -**\xa0Use your Ice Blast!_\n\n### _**FireCrawlers**_\\[[](https://au ...
#  Document(page_content=' \n\nClose search\n\nJust added to your cart\n-----------------------\n\nQty:\n\n[View cart ()](/cart)\n\nContinue shopping\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_300x300.jpg?v=1661392828)\n\n![Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbaitClose........_300x300.jpg?v=1661392822)\n\n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_110x110@2x.jpg?v=1661392828)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_1024x1024@2x.jpg?v=1661392828)\n    \n*   [![Load image into Gallery viewer, Fire Craw](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbaitClose........_110x110@2x.jpg?v=1661392822)](//www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbaitClose........_1024x1024@2x.jpg?v=1661392822)\n    \n\nFire Craw\n=========\n\nWrite a review\n\nRegular price\n\n$5.99\n\nSale price\n\n$5.99 Sale\n\nUnit price\n\n/per\xa0\n\nAdding product to your cart\n\nSwimbaits are a go to for many anglers. It is an extremely versatile bait that can be fished many different ways; Texas Rig, Spinnerbait, Jig Trailer, Umbrella Rig, and even a Carolina Rig. The ribbed body creates alot of water movement to make even the most finicky fish bite it.\n\nUse left/right arrows to navigate the slideshow or swipe left/right if using a mobile device\n\n*   choosing a selection results in a full page refresh\n*   press the space key then arrow keys to make a selection\n\n*   Opens in a new window.\n*   Opens external website.\n*   Opens external website in a new window.', metadata={'title': "Fire Craw\n– Moorer's Bait CompanyAmazonAmerican ExpressApple PayDiscoverMeta PayGoogle PayMastercardPayPalShop PayVenmoVisa", 'description': 'Swimbaits are a go to for many anglers. It is an extremely versatile bait that can be fished many different ways; Texas Rig, Spinnerbait, Jig Trailer, Umbrella Rig, and even a Carolina Rig. The ribbed body creates alot of water movement to make even the most finicky fish bite it.', 'ogTitle': 'Fire Craw', 'ogDescription': 'Swimbaits are a go to for many anglers. It is an extremely versatile bait that can be fished many different ways; Texas Rig, Spinnerbait, Jig Trailer, Umbrella Rig, and even a Carolina Rig. The ribbed body creates alot of water movement to make even the most finicky fish bite it.', 'ogUrl': 'https://www.moorersbaitcompany.com/products/fire-craw', 'ogImage': 'http://www.moorersbaitcompany.com/cdn/shop/products/FireCrawSwimbait_1200x1200.jpg?v=1661392828', 'ogLocaleAlternate': [], 'ogSiteName': "Moorer's Bait Company", 'sourceURL': 'https://www.moorersbaitcompany.com/products/fire-craw'})]

# %% [markdown]
# #### Search Options
#
# You can also pass `params` to the loader. This is a dictionary of options to pass to the loader. See the [FireCrawl API documentation](https://github.com/mendableai/firecrawl-py) for more information.
